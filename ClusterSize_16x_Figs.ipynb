# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import csv

run=50
t=300
cadence=26
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*cadence) for i in t_list_years]

# %% [markdown]
# ## Number of bursts happening at any given time
# This is the number of bursts that are physically happening at any given time during the simulation, specifically
# the times at which we want to observe

# %%
values50table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values50_16x')
burst_total50_2week=values50table_2week['burst_total'] 
burst_fraction50_2week=values50table_2week['burst_number'] 

values100table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values100_16x')
burst_total100_2week=values100table_2week['burst_total'] 
burst_fraction100_2week=values100table_2week['burst_number'] 

values500table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values500_16x')
burst_total500_2week=values500table_2week['burst_total'] 
burst_fraction500_2week=values500table_2week['burst_number'] 

values1000table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values1000_16x')
burst_total1000_2week=values1000table_2week['burst_total'] 
burst_fraction1000_2week=values1000table_2week['burst_number'] 

values2000table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values2000_16x')
burst_total2000_2week=values2000table_2week['burst_total'] 
burst_fraction2000_2week=values2000table_2week['burst_number'] 

values5000table_2week=ascii.read('/home/lee/data/cluster_size_change/16x_burst/values5000_16x')
burst_total5000_2week=values5000table_2week['burst_total'] 
burst_fraction5000_2week=values5000table_2week['burst_number']

# %%
cadence_num_bursts50_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts50_2week.append(burst_fraction50_2week[i][j])
        
cadence_num_bursts100_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts100_2week.append(burst_fraction100_2week[i][j])
        
cadence_num_bursts500_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts500_2week.append(burst_fraction500_2week[i][j])
        
cadence_num_bursts1000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_2week.append(burst_fraction1000_2week[i][j])
        
cadence_num_bursts2000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts2000_2week.append(burst_fraction2000_2week[i][j])

cadence_num_bursts5000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts5000_2week.append(burst_fraction5000_2week[i][j])

print(cadence_num_bursts5000_2week)
# Out:
# [293, 271, 304, 317, 314, 302, 279, 298, 306, 303, 287, 287, 304, 304, 329, 310, 272, 298, 318, 286, 276, 289, 273, 281, 277, 310, 299, 315, 299, 263, 276, 288, 289, 297, 297, 307, 343, 308, 311, 300, 262, 272, 298, 303, 295, 278, 274, 272, 307, 315, 303, 285, 289, 302, 296, 292, 323, 341, 321, 292, 295, 297, 305, 293, 289, 291, 301, 291, 257, 288, 310, 293, 283, 310, 317, 282, 256, 260, 283, 288, 311, 313, 295, 310, 287, 297, 321, 338, 322, 301, 310, 303, 278, 271, 284, 309, 293, 295, 310, 310, 290, 268, 256, 266, 295, 287, 281, 302, 307, 301, 304, 280, 262, 288, 308, 311, 312, 287, 286, 288, 318, 282, 285, 268, 268, 287, 292, 252, 261, 296, 305, 322, 332, 305, 322, 302, 272, 278, 314, 314, 294, 280, 278, 290, 291, 303, 297, 279, 278, 307, 303, 312, 315, 308, 323, 309, 318, 281, 302, 311, 314, 308, 289, 269, 295, 323, 310, 310, 305, 277, 285, 284, 303, 282, 296, 312, 306, 306, 294, 292, 288, 303, 300, 306, 280, 286, 298, 291, 286, 310, 306, 314, 300, 299, 310, 309, 310, 298, 281, 276, 289, 311, 297, 282, 277, 304, 313, 312, 301, 282, 276, 284, 289, 281, 292, 302, 321, 296, 308, 294, 296, 304, 286, 281, 281, 274, 305, 320, 294, 286, 295, 319, 317, 298, 277, 283, 285, 288, 294, 290, 295, 332, 300, 264, 262, 278, 278, 280, 284, 290, 295, 316, 343, 323, 324, 314, 339, 311, 275, 285, 286, 283, 293, 282, 269, 303, 262, 270, 294, 317, 349, 300, 284, 297, 279, 291, 301, 318, 327, 295, 276, 280, 274, 296, 298, 267, 287, 300, 304, 308, 285, 289, 269, 255, 266, 283, 307, 299, 279, 276, 299, 280, 296, 291, 291, 312, 305, 311, 308, 292, 280, 267, 287, 312, 305, 278, 273, 273, 294, 293, 294, 294, 272, 281, 301, 288, 298, 288, 264, 259, 289, 302, 297, 316, 325, 290, 298, 264, 279, 296, 272, 266, 286, 312, 307, 297, 310, 319, 281, 316, 357, 334, 283, 251, 269, 316, 323, 315, 302, 316, 331, 283, 280, 308, 311, 290, 318, 323, 298, 306, 295, 271, 252, 306, 294, 296, 314, 316, 310, 290, 307, 327, 294, 291, 301, 309, 311, 319, 288, 272, 279, 288, 308, 314, 301, 313, 309, 302, 312, 305, 313, 285, 260, 278, 279, 287, 295, 314, 278, 289, 302, 297, 305, 306, 284, 281, 300, 302, 289, 312, 306, 294, 298, 279, 286, 291, 299, 299, 281, 290, 300, 296, 284, 265, 261, 269, 296, 314, 280, 298, 308, 312, 310, 282, 321, 285, 263, 253, 285, 303, 290, 285, 317, 322, 284, 282, 299, 297, 281, 302, 317, 307, 314, 299, 309, 312, 291, 318, 300, 321, 302, 292, 297, 283, 298, 295, 274, 286, 287, 273, 326, 291, 281, 259, 269, 290, 304, 307, 283, 280, 304, 293, 303, 276, 295, 316, 301, 294, 282, 285, 296, 283, 280, 305, 293, 294, 268, 273, 292, 305, 284, 294, 316, 278, 271, 287, 256, 283, 296, 295, 284, 287, 285, 313, 331, 301, 291, 309, 295, 316, 306, 308, 310, 305, 302, 303, 293, 288, 293, 274, 302, 304, 298, 319, 315, 291, 288, 290, 271, 268, 316, 305, 283, 300, 308, 306, 304, 291, 315, 306, 275, 290, 271, 279, 295, 286, 302, 291, 278, 301, 308, 278, 288, 312, 332, 311, 290, 278, 291, 305, 292, 293, 296, 300, 296, 283, 274, 269, 300, 301, 284, 293, 322, 315, 315, 318, 326, 317, 288, 279]

# %%
data_num_2week=[cadence_num_bursts50_2week,cadence_num_bursts100_2week,cadence_num_bursts500_2week,\
                cadence_num_bursts1000_2week,cadence_num_bursts2000_2week,cadence_num_bursts5000_2week]

labels=[50,100,500,1000,2000,5000]
fig,ax=plt.subplots()
fig.set_size_inches(9,8)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'
ax.violinplot(data_num_2week,vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
plt.xticks([1,2,3,4,5,6,],['50','100','500','1000','2000','5000'])
ax.set_xlabel('Number of Stars in Cluster',fontsize=13)
ax.set_ylabel('Number of Bursts',fontsize=13)
ax.set_title('Number of 16x Burst for Different Cluster Sizes (Any Time)',fontsize=15)
plt.plot()
plt.savefig('/home/lee/research/figs/SizeChange/violinplots/number/16x_burst/violin_plot_50run_16x_normal.jpeg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Number of bursts that are happening during an entire observing program
# This is the number of bursts physically happening during our observing program, taking only the data from the dates
# in which we would like to observe the cluster

# %% [markdown]
# ## 50 stars

# %%
burst50=np.load('/home/lee/data/cluster_size_change/16x_burst/burst50_16x.npy')
L50=np.load('/home/lee/data/cluster_size_change/16x_burst/L50_16x.npy')
C50=np.load('/home/lee/data/cluster_size_change/16x_burst/C50_16x.npy')

# %%
cluster_size50=50
cad_C50=np.zeros((run,cluster_size50,12))
for i in range(run):
    for j in range(cluster_size50):
        for k in range(len(t_list_cadence)):
                cad_C50[i,j,k]=C50[i,j,t_list_cadence[k]]

# %%
print(np.shape(cad_C50))
# Out:
# (50, 50, 12)

# %%
num50=0
num50_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size50):
            if cad_C50[i,k,j]==16 and cad_C50[i,k,j]!=cad_C50[i,k,j-1]:
                num50+=1
    num50_list.append(num50)
    num50=0

# %%
print(num50_list)
# Out:
# [24, 20, 19, 17, 21, 24, 21, 14, 23, 31, 10, 21, 15, 23, 22, 19, 20, 20, 22, 20, 28, 22, 18, 20, 18, 26, 19, 20, 18, 19, 25, 19, 18, 17, 13, 16, 20, 21, 22, 25, 21, 23, 23, 13, 17, 17, 18, 16, 17, 22]

# %% [markdown]
# ## 100 stars

# %%
burst100=np.load('/home/lee/data/cluster_size_change/16x_burst/burst100_16x.npy')
L100=np.load('/home/lee/data/cluster_size_change/16x_burst/L100_16x.npy')
C100=np.load('/home/lee/data/cluster_size_change/16x_burst/C100_16x.npy')

# %%
cluster_size100=100
cad_C100=np.zeros((run,cluster_size100,12))
for i in range(run):
    for j in range(cluster_size100):
        for k in range(len(t_list_cadence)):
                cad_C100[i,j,k]=C100[i,j,t_list_cadence[k]]

# %%
num100=0
num100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size100):
            if cad_C100[i,k,j]==16 and cad_C100[i,k,j]!=cad_C100[i,k,j-1]:
                num100+=1
    num100_list.append(num100)
    num100=0

# %%
print(num100_list)
# Out:
# [36, 26, 38, 42, 37, 57, 40, 40, 27, 51, 48, 31, 52, 41, 36, 38, 48, 34, 40, 42, 34, 47, 42, 36, 37, 35, 35, 52, 34, 42, 36, 42, 50, 44, 42, 45, 39, 30, 35, 40, 36, 37, 41, 41, 49, 37, 37, 39, 41, 42]

# %% [markdown]
# ## 500 stars

# %%
burst500=np.load('/home/lee/data/cluster_size_change/16x_burst/burst500_16x.npy')
L500=np.load('/home/lee/data/cluster_size_change/16x_burst/L500_16x.npy')
C500=np.load('/home/lee/data/cluster_size_change/16x_burst/C500_16x.npy')

# %%
cluster_size500=500
cad_C500=np.zeros((run,cluster_size500,12))
for i in range(run):
    for j in range(cluster_size500):
        for k in range(len(t_list_cadence)):
                cad_C500[i,j,k]=C500[i,j,t_list_cadence[k]]

# %%
num500=0
num500_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size500):
            if cad_C500[i,k,j]==16 and cad_C500[i,k,j]!=cad_C500[i,k,j-1]:
                num500+=1
    num500_list.append(num500)
    num500=0

# %%
print(num500_list)
# Out:
# [196, 193, 185, 174, 191, 177, 208, 191, 219, 215, 211, 207, 200, 185, 199, 192, 203, 183, 197, 177, 191, 204, 177, 229, 220, 197, 184, 215, 200, 192, 222, 194, 212, 181, 212, 176, 185, 215, 205, 202, 228, 208, 198, 190, 202, 201, 220, 201, 205, 195]

# %% [markdown]
# ## 1000 stars

# %%
burst1000=np.load('/home/lee/data/cluster_size_change/16x_burst/burst1000_16x.npy')
L1000=np.load('/home/lee/data/cluster_size_change/16x_burst/L1000_16x.npy')
C1000=np.load('/home/lee/data/cluster_size_change/16x_burst/C1000_16x.npy')

# %%
cluster_size1000=1000
cad_C1000=np.zeros((run,cluster_size1000,12))
for i in range(run):
    for j in range(cluster_size1000):
        for k in range(len(t_list_cadence)):
                cad_C1000[i,j,k]=C1000[i,j,t_list_cadence[k]]

# %%
num1000=0
num1000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size1000):
            if cad_C1000[i,k,j]==16 and cad_C1000[i,k,j]!=cad_C1000[i,k,j-1]:
                num1000+=1
    num1000_list.append(num1000)
    num1000=0

# %%
print(num1000_list)
# Out:
# [388, 407, 373, 419, 419, 451, 432, 393, 390, 421, 377, 393, 419, 409, 397, 410, 399, 375, 393, 395, 381, 390, 414, 401, 372, 364, 401, 410, 391, 385, 436, 417, 409, 437, 370, 398, 419, 379, 392, 398, 382, 413, 371, 411, 384, 399, 401, 390, 400, 387]

# %% [markdown]
# ## 2000 stars

# %%
burst2000=np.load('/home/lee/data/cluster_size_change/16x_burst/burst2000_16x.npy')
L2000=np.load('/home/lee/data/cluster_size_change/16x_burst/L2000_16x.npy')
C2000=np.load('/home/lee/data/cluster_size_change/16x_burst/C2000_16x.npy')

# %%
cluster_size2000=2000
cad_C2000=np.zeros((run,cluster_size2000,12))
for i in range(run):
    for j in range(cluster_size2000):
        for k in range(len(t_list_cadence)):
                cad_C2000[i,j,k]=C2000[i,j,t_list_cadence[k]]

# %%
num2000=0
num2000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size2000):
            if cad_C2000[i,k,j]==16 and cad_C2000[i,k,j]!=cad_C2000[i,k,j-1]:
                num2000+=1
    num2000_list.append(num2000)
    num2000=0

# %%
print(num2000_list)
# Out:
# [806, 761, 824, 792, 808, 812, 771, 775, 780, 801, 825, 839, 805, 801, 839, 753, 834, 793, 744, 745, 779, 832, 768, 816, 805, 746, 817, 770, 848, 808, 813, 783, 751, 811, 776, 737, 760, 830, 775, 753, 810, 789, 831, 823, 808, 814, 833, 828, 808, 780]

# %% [markdown]
# ## 5000 stars

# %%
burst5000=np.load('/home/lee/data/cluster_size_change/16x_burst/burst5000_16x.npy')
L5000=np.load('/home/lee/data/cluster_size_change/16x_burst/L5000_16x.npy')
C5000=np.load('/home/lee/data/cluster_size_change/16x_burst/C5000_16x.npy')

# %%
cluster_size5000=5000
cad_C5000=np.zeros((run,cluster_size5000,12))
for i in range(run):
    for j in range(cluster_size5000):
        for k in range(len(t_list_cadence)):
                cad_C5000[i,j,k]=C5000[i,j,t_list_cadence[k]]

# %%
num5000=0
num5000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size5000):
            if cad_C5000[i,k,j]==16 and cad_C5000[i,k,j]!=cad_C5000[i,k,j-1]:
                num5000+=1
    num5000_list.append(num5000)
    num5000=0

# %%
print(num5000_list)
# Out:
# [2012, 2011, 2004, 2022, 2078, 1989, 1986, 2051, 1956, 1987, 1962, 2032, 2050, 2049, 2003, 2025, 2004, 1987, 2015, 2010, 2008, 2065, 2000, 2005, 1953, 1988, 1970, 1974, 1989, 2070, 2052, 2028, 2052, 2024, 2022, 1992, 1964, 1977, 2083, 1988, 1991, 2011, 1965, 1978, 2036, 2028, 2008, 2013, 1970, 2057]

# %% [markdown]
# ## log scale

# %%
num_new50=[]
num_new100=[]
num_new500=[]
num_new1000=[]
num_new2000=[]
num_new5000=[]
for i in range(len(num50_list)):
    if num50_list[i]!=0:
        num_new50.append(num50_list[i])
        
for i in range(len(num100_list)):
    if num100_list[i]!=0:
        num_new100.append(num100_list[i])
        
for i in range(len(num500_list)):
    if num500_list[i]!=0:
        num_new500.append(num500_list[i])
        
for i in range(len(num1000_list)):
    if num1000_list[i]!=0:
        num_new1000.append(num1000_list[i])
        
for i in range(len(num2000_list)):
    if num2000_list[i]!=0:
        num_new2000.append(num2000_list[i])
        
for i in range(len(num5000_list)):
    if num5000_list[i]!=0:
        num_new5000.append(num5000_list[i])

# %%
data_num=[num_new50,num_new100,num_new500,num_new1000,num_new2000,num_new5000]
print(data_num)
# Out:
# [[24, 20, 19, 17, 21, 24, 21, 14, 23, 31, 10, 21, 15, 23, 22, 19, 20, 20, 22, 20, 28, 22, 18, 20, 18, 26, 19, 20, 18, 19, 25, 19, 18, 17, 13, 16, 20, 21, 22, 25, 21, 23, 23, 13, 17, 17, 18, 16, 17, 22], [36, 26, 38, 42, 37, 57, 40, 40, 27, 51, 48, 31, 52, 41, 36, 38, 48, 34, 40, 42, 34, 47, 42, 36, 37, 35, 35, 52, 34, 42, 36, 42, 50, 44, 42, 45, 39, 30, 35, 40, 36, 37, 41, 41, 49, 37, 37, 39, 41, 42], [196, 193, 185, 174, 191, 177, 208, 191, 219, 215, 211, 207, 200, 185, 199, 192, 203, 183, 197, 177, 191, 204, 177, 229, 220, 197, 184, 215, 200, 192, 222, 194, 212, 181, 212, 176, 185, 215, 205, 202, 228, 208, 198, 190, 202, 201, 220, 201, 205, 195], [388, 407, 373, 419, 419, 451, 432, 393, 390, 421, 377, 393, 419, 409, 397, 410, 399, 375, 393, 395, 381, 390, 414, 401, 372, 364, 401, 410, 391, 385, 436, 417, 409, 437, 370, 398, 419, 379, 392, 398, 382, 413, 371, 411, 384, 399, 401, 390, 400, 387], [806, 761, 824, 792, 808, 812, 771, 775, 780, 801, 825, 839, 805, 801, 839, 753, 834, 793, 744, 745, 779, 832, 768, 816, 805, 746, 817, 770, 848, 808, 813, 783, 751, 811, 776, 737, 760, 830, 775, 753, 810, 789, 831, 823, 808, 814, 833, 828, 808, 780], [2012, 2011, 2004, 2022, 2078, 1989, 1986, 2051, 1956, 1987, 1962, 2032, 2050, 2049, 2003, 2025, 2004, 1987, 2015, 2010, 2008, 2065, 2000, 2005, 1953, 1988, 1970, 1974, 1989, 2070, 2052, 2028, 2052, 2024, 2022, 1992, 1964, 1977, 2083, 1988, 1991, 2011, 1965, 1978, 2036, 2028, 2008, 2013, 1970, 2057]]

# %%
labels=[50,100,500,1000,2000,5000]
fig,ax=plt.subplots()
fig.set_size_inches(9,8)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'
ax.violinplot(data_num,vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
plt.xticks([1,2,3,4,5,6,],['50','100','500','1000','2000','5000'])
ax.set_xlabel('Number of Stars in Cluster',fontsize=13)
ax.set_ylabel('Number of Bursts',fontsize=13)
ax.set_title('Number of 16x Bursts for Different Cluster Sizes (Entire Observing Program)',fontsize=14)
plt.plot()
plt.savefig('/home/lee/research/figs/SizeChange/violinplots/number/16x_burst/observing_run_16x.jpeg',dpi=300,bbox_inches='tight')
