# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import csv

run=50
t=300
cadence=26
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*cadence) for i in t_list_years]
cluster_size=2000

t_list=np.linspace(220,225,130)
t_list_int=[int(i*cadence) for i in t_list]

#t_list_100true=t_list
t_list_100true=np.append(t_list,[200])
t_list_100true.sort()
t_list_100true_int=[int(i*cadence) for i in t_list_100true]

print(len(t_list_100true))
# Out:
# 131

# %% [markdown]
# # Expected

# %%
prob100_1bin=3.33e-4
total100_1bin=prob100_1bin*2000*25
print(total100_1bin*2)
# Out:
# 33.300000000000004

# %%
prob100_2bin=1.67e-4
total100_2bin=prob100_2bin*2000*25
prob40_2bin=4.17e-3
total40_2bin=prob40_2bin*2000*5
print(total100_2bin,total40_2bin)
# Out:
# 8.35 41.7

# %%
prob100_3bin=1.11e-4
total100_3bin=prob100_3bin*2000*25
prob40_3bin=2.78e-3
total40_3bin=prob40_3bin*2000*25
prob16_3bin=0.0208
total16_3bin=prob16_3bin*2000*25
print(total100_3bin,total40_3bin,total16_3bin)
# Out:
# 5.55 139.0 1040.0

# %%
prob100_4bin=8.33e-5
total100_4bin=prob100_4bin*2000*25
prob40_4bin=2.08e-3
total40_4bin=prob40_4bin*2000*25
prob16_4bin=0.0156
total16_4bin=prob16_4bin*2000*25
prob3_4bin=2.083
total3_4bin=prob3_4bin*2000*25
print(total100_4bin,total40_4bin,total16_4bin,total3_4bin)
# Out:
# 4.165 103.99999999999999 780.0 104150.0

# %%
prob100_5bin=6.67e-5
prob40_5bin=1.67e-3
prob16_5bin= 0.0125
prob3_5bin=1.667
prob6_5bin=0.011

total100_5bin=prob100_5bin*2000*25
total40_5bin=prob40_5bin*2000*25
total16_5bin=prob16_5bin*2000*25
total3_5bin=prob3_5bin*2000*25
total6_5bin=prob6_5bin*2000*25
print(total100_5bin,total40_5bin,total16_5bin,total3_5bin,total6_5bin)
# Out:
# 3.335 83.50000000000001 625.0 83350.0 550.0

# %% [markdown]
# # Actual number of bursts in the program

# %% [markdown]
# ## 1 bin

# %%
C2000_1bin=np.load('/home/lee/data/2000stars_only/C2000_1.npy')

cad_C2000_1bin=np.zeros((run,cluster_size,len(t_list_100true_int)))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_100true_int)):
                cad_C2000_1bin[i,j,k]=C2000_1bin[i,j,t_list_100true_int[k]]

# %%
num2000_1bin100=0
num2000_1bin100_list=[]
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_100true_int)):
            if j==0:
                if cad_C2000_1bin[i,j,k]==100:
                    num2000_1bin100+=1
            else:
                if cad_C2000_1bin[i,j,k]==100 and cad_C2000_1bin[i,j,k-1]!=100:
                    num2000_1bin100+=1
    num2000_1bin100_list.append(num2000_1bin100)
    num2000_1bin100=0

# %%
print(np.mean(num2000_1bin100_list))
# Out:
# 37.04

# %% [markdown]
# ## 2 bin

# %% [markdown]
# ### 100

# %%
C2000_2bin=np.load('/home/lee/data/2000stars_only/C2000_2.npy')

cad_C2000_2bin=np.zeros((run,cluster_size,len(t_list_100true_int)))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_100true_int)):
                cad_C2000_2bin[i,j,k]=C2000_2bin[i,j,t_list_100true_int[k]]

# %%
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_100true_int)):
            if C2000_2bin[i,j,k]==100:
                print('true')
# Out:
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# ...

# %%
num2000_2bin100=0
num2000_2bin100_list=[]
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_100true_int)):
            if j==0:
                if cad_C2000_2bin[i,j,k]==100:
                    num2000_2bin100+=1
            else:
                if cad_C2000_2bin[i,j,k]==100 and cad_C2000_2bin[i,j,k-1]!=100:
                    num2000_2bin100+=1
    num2000_2bin100_list.append(num2000_2bin100)
    num2000_2bin100=0

# %%
print(np.mean(num2000_2bin100_list))
# Out:
# 21.16

# %% [markdown]
# ### 40

# %%
N2000_2bin=np.load('/home/lee/data/2000stars_only/final_2000_2.npy')

cad_N2000_2bin=np.zeros((run,cluster_size,130))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_int)):
                cad_N2000_2bin[i,j,k]=N2000_2bin[i,j,t_list_int[k]]

# %%
num2000_2bin40=0
num2000_2bin40_list=[]
for i in range(run):
    for j in range(0,130):
        for k in range(cluster_size):
            if j<78:
                if cad_N2000_2bin[i,k,j]==40:
                    num2000_2bin40+=2
            elif j>52:
                if cad_N2000_2bin[i,k,j]==40:
                    num2000_2bin40+=2
            else:
                if cad_N2000_2bin[i,k,j]==40:
                    num2000_2bin40+=1
    num2000_2bin40_list.append(num2000_2bin40)
    num2000_2bin40=0

# %%
print(np.mean(num2000_2bin100_list))
print(np.mean(num2000_2bin40_list))
# Out:
# 15.96
# 78.0

# %% [markdown]
# ## 3 bin

# %%
N2000_3bin=np.load('/home/lee/data/2000stars_only/final_2000_3.npy')

cad_N2000_3bin=np.zeros((run,cluster_size,651))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_int)):
                cad_N2000_3bin[i,j,k]=N2000_3bin[i,j,t_list_int[k]]

# %%
num2000_3bin100=0
num2000_3bin100_list=[]
num2000_3bin40=0
num2000_3bin40_list=[]
num2000_3bin16=0
num2000_3bin16_list=[]
for i in range(run):
    for j in range(0,651):
        for k in range(cluster_size):
            if cad_N2000_3bin[i,k,j]==100:
                num2000_3bin100+=1
            elif cad_N2000_3bin[i,k,j]==40:
                num2000_3bin40+=1
            elif cad_N2000_3bin[i,k,j]==16:
                num2000_3bin16+=1
    num2000_3bin100_list.append(num2000_3bin100)
    num2000_3bin100=0
    num2000_3bin40_list.append(num2000_3bin40)
    num2000_3bin40=0
    num2000_3bin16_list.append(num2000_3bin16)
    num2000_3bin16=0

# %%
print(np.mean(num2000_3bin100_list))
# Out:
# 4.94

# %% [markdown]
# ## 4 bin

# %%
N2000_4bin=np.load('/home/lee/data/2000stars_only/final_2000_4.npy')

cad_N2000_4bin=np.zeros((run,cluster_size,651))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_int)):
                cad_N2000_4bin[i,j,k]=N2000_4bin[i,j,t_list_int[k]]

# %%
num2000_4bin100=0
num2000_4bin100_list=[]
num2000_4bin40=0
num2000_4bin40_list=[]
num2000_4bin16=0
num2000_4bin16_list=[]
num2000_4bin3=0
num2000_4bin3_list=[]
for i in range(run):
    for j in range(0,651):
        for k in range(cluster_size):
            if cad_N2000_4bin[i,k,j]==100:
                num2000_4bin100+=1
            elif cad_N2000_4bin[i,k,j]==40:
                num2000_4bin40+=1
            elif cad_N2000_4bin[i,k,j]==16:
                num2000_4bin16+=1
            elif cad_N2000_4bin[i,k,j]==3:
                num2000_4bin3+=1
    num2000_4bin100_list.append(num2000_4bin100)
    num2000_4bin100=0
    num2000_4bin40_list.append(num2000_4bin40)
    num2000_4bin40=0
    num2000_4bin16_list.append(num2000_4bin16)
    num2000_4bin16=0
    num2000_4bin3_list.append(num2000_4bin3)
    num2000_4bin3=0

# %%
print(np.mean(num2000_4bin16_list))
# Out:
# 687.16

# %% [markdown]
# ## 5 bin

# %%
N2000_5bin=np.load('/home/lee/data/2000stars_only/final_2000_5.npy')

cad_N2000_5bin=np.zeros((run,cluster_size,651))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_int)):
                cad_N2000_5bin[i,j,k]=N2000_5bin[i,j,t_list_int[k]]

# %%
num2000_5bin100=0
num2000_5bin100_list=[]
num2000_5bin40=0
num2000_5bin40_list=[]
num2000_5bin16=0
num2000_5bin16_list=[]
num2000_5bin3=0
num2000_5bin3_list=[]
num2000_5bin6=0
num2000_5bin6_list=[]
for i in range(run):
    for j in range(0,651):
        for k in range(cluster_size):
            if cad_N2000_5bin[i,k,j]==100:
                num2000_5bin100+=1
            elif cad_N2000_5bin[i,k,j]==40:
                num2000_5bin40+=1
            elif cad_N2000_5bin[i,k,j]==16:
                num2000_5bin16+=1
            elif cad_N2000_5bin[i,k,j]==3:
                num2000_5bin3+=1
            elif cad_N2000_5bin[i,k,j]==6:
                num2000_5bin6+=1
    num2000_5bin100_list.append(num2000_5bin100)
    num2000_5bin100=0
    num2000_5bin40_list.append(num2000_5bin40)
    num2000_5bin40=0
    num2000_5bin16_list.append(num2000_5bin16)
    num2000_5bin16=0
    num2000_5bin3_list.append(num2000_5bin3)
    num2000_5bin3=0
    num2000_5bin6_list.append(num2000_5bin6)
    num2000_5bin6=0

# %%
print(np.mean(num2000_5bin100_list))
# Out:
# 3.0

# %% [markdown]
# # What we observe

# %%
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*cadence) for i in t_list_years]
cluster_size=2000

# %% [markdown]
# ## 1 bin

# %%
L2000_1bin=np.load('/home/lee/data/2000stars_only/L2000_1.npy')

cluster_size=2000

cad_L2000_1binObs=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_L2000_1binObs[i,j,k]=L2000_1bin[i,j,t_list_cadence[k]]


num2000_1bin100_total=0
list2000_1bin100_total=[]
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_1binObs[i,k,j]-cad_L2000_1binObs[i,k,j-1]==5:
                num2000_1bin100_total+=1
                print(i,k,j)
    list2000_1bin100_total.append(num2000_1bin100_total)
    num2000_1bin100_total=0
# Out:
# 0 54 9
# 0 71 1
# 0 121 8
# 0 161 1
# 0 387 1
# 0 680 1
# 0 720 11
# 0 985 1
# 0 1252 1
# 0 1434 1
# 0 1437 1
# 0 1486 1
# 0 1531 1
# 0 1585 10
# 0 1613 1
# 0 1623 1
# 0 1795 1
# 1 53 1
# 1 98 1
# 1 144 1
# 1 165 1
# 1 195 1
# 1 399 1
# 1 499 1
# 1 507 1
# 1 547 1
# 1 551 5
# 1 684 1
# 1 736 4
# 1 882 1
# 1 1218 1
# 1 1397 1
# 1 1891 1
# 2 126 1
# 2 215 1
# 2 295 1
# 2 299 2
# 2 336 1
# 2 573 1
# 2 584 1
# 2 730 8
# 2 1124 1
# 2 1296 3
# 2 1407 1
# 2 1518 1
# 2 1687 5
# 2 1715 1
# 2 1934 7
# 3 37 1
# 3 57 5
# 3 320 1
# 3 327 1
# 3 678 1
# 3 880 1
# 3 1332 7
# 3 1450 1
# 3 1622 1
# 4 120 3
# 4 176 1
# 4 594 3
# 4 610 1
# 4 865 11
# 4 1226 1
# 4 1654 1
# 4 1788 1
# 4 1803 1
# 4 1908 6
# 5 427 1
# 5 448 1
# 5 474 1
# 5 888 1
# 5 939 1
# 5 1402 7
# 5 1407 1
# 6 621 1
# 6 637 1
# 6 941 1
# 6 950 1
# 6 972 1
# 6 1046 9
# 6 1340 1
# 6 1619 1
# 6 1848 1
# 7 135 1
# 7 342 1
# 7 405 1
# 7 464 3
# 7 598 1
# 7 600 11
# 7 650 1
# 7 867 1
# 7 874 1
# 7 1026 1
# 7 1053 1
# 7 1142 1
# 7 1377 1
# ...

# %%
print(cad_L2000_1binObs[0,720,:])
# Out:
# [-0.46243798 -0.46243798 -0.46243798 -0.46243798 -0.46243798 -0.46243798
#  -0.46243798 -0.46243798 -0.46243798 -0.46243798 -0.46243798  4.53756202]

# %%
print(np.mean(list2000_1bin100_total))
# Out:
# 31.88

# %% [markdown]
# ## 2 bin

# %%
L2000_2bin=np.load('/home/lee/data/2000stars_only/L2000_2.npy')

cluster_size=2000

cad_L2000_2binObs=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_L2000_2binObs[i,j,k]=L2000_2bin[i,j,t_list_cadence[k]]

obs_burst2bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_2binObs[i,k,j]-cad_L2000_2binObs[i,k,j-1]==5:
                    obs_burst2bin[i,k,j-30:j]=100
            elif cad_L2000_2binObs[i,k,j-1]-cad_L2000_2binObs[i,k,j]==5:
                    obs_burst2bin[i,k,j:j+30]=100

#40
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_2binObs[i,k,j]-cad_L2000_2binObs[i,k,j-1]==4:
                    obs_burst2bin[i,k,j-1]=40
                elif cad_L2000_2binObs[i,k,j-1]-cad_L2000_2binObs[i,k,j]==4:
                    if cad_L2000_2binObs[i,k,j]!=cad_L2000_2binObs[i,k,j+1]:
                        obs_burst2bin[i,k,j]=40
                    elif cad_L2000_2binObs[i,k,j]==cad_L2000_2binObs[i,k,j+1]:
                        obs_burst2bin[i,k,j:j+2]=40
            else:
                if cad_L2000_2binObs[i,k,j]-cad_L2000_2binObs[i,k,j-1]==4:
                    obs_burst2bin[i,k,j-6:j]=40
                    obs_burst2bin[i,k,0]=0
                elif cad_L2000_2binObs[i,k,j-1]-cad_L2000_2binObs[i,k,j]==4:
                    obs_burst2bin[i,k,j:j+6]=40

num2000_2bin40=0
list2000_2bin40=[]
num2000_2bin100=0
list2000_2bin100=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if obs_burst2bin[i,k,j]==100:
                num2000_2bin100+=1
            elif obs_burst2bin[i,k,j]==40:
                num2000_2bin40+=1
        list2000_2bin40.append(num2000_2bin40)
        num2000_2bin40=0
        list2000_2bin100.append(num2000_2bin100)
        num2000_2bin100=0

num2000_2bin40_total=0
list2000_2bin40_total=[]
num2000_2bin100_total=0
list2000_2bin100_total=[]
for i in range(run):
    for j in range(1,12):
        for k in range(cluster_size):
            if obs_burst2bin[i,k,j]==100 and obs_burst2bin[i,k,j-1]!=100:
                num2000_2bin100_total+=1
            elif obs_burst2bin[i,k,j-1]==100 and obs_burst2bin[i,k,j]!=100:
                num2000_2bin100_total+=1
            elif j==1 and obs_burst2bin[i,k,j-1]==40 and obs_burst2bin[i,k,j]!=40:
                num2000_2bin40_total+=1
            elif obs_burst2bin[i,k,j]==40 and obs_burst2bin[i,k,j-1]!=40:
                num2000_2bin40_total+=1
    list2000_2bin40_total.append(num2000_2bin40_total)
    num2000_2bin40_total=0
    list2000_2bin100_total.append(num2000_2bin100_total)
    num2000_2bin100_total=0

# %%
print(np.mean(list2000_2bin40_total))
# Out:
# 76.9

# %% [markdown]
# ## 3 bins

# %%
L2000_3bin=np.load('/home/lee/data/2000stars_only/L2000_3.npy')

cluster_size=2000

cad_L2000_3binObs=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_L2000_3binObs[i,j,k]=L2000_3bin[i,j,t_list_cadence[k]]

obs_burst3bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_3binObs[i,k,j]-cad_L2000_3binObs[i,k,j-1]==5:
                    obs_burst3bin[i,k,j-30:j]=100
            elif cad_L2000_3binObs[i,k,j-1]-cad_L2000_3binObs[i,k,j]==5:
                    obs_burst3bin[i,k,j:j+30]=100

#40
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_3binObs[i,k,j]-cad_L2000_3binObs[i,k,j-1]==4:
                    obs_burst3bin[i,k,j-1]=40
                elif cad_L2000_3binObs[i,k,j-1]-cad_L2000_3binObs[i,k,j]==4:
                    if cad_L2000_3binObs[i,k,j]!=cad_L2000_3binObs[i,k,j+1]:
                        obs_burst3bin[i,k,j]=40
                    elif cad_L2000_3binObs[i,k,j]==cad_L2000_3binObs[i,k,j+1]:
                        obs_burst3bin[i,k,j:j+2]=40
            else:
                if cad_L2000_3binObs[i,k,j]-cad_L2000_3binObs[i,k,j-1]==4:
                    obs_burst3bin[i,k,j-6:j]=40
                    obs_burst3bin[i,k,0]=0
                elif cad_L2000_3binObs[i,k,j-1]-cad_L2000_3binObs[i,k,j]==4:
                    obs_burst3bin[i,k,j:j+6]=40

#16
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_3binObs[i,k,j]-cad_L2000_3binObs[i,k,j-1]==3:
                    obs_burst3bin[i,k,j-1]=16
                elif cad_L2000_3binObs[i,k,j-1]-cad_L2000_3binObs[i,k,j]==3:
                    if cad_L2000_3binObs[i,k,j]!=cad_L2000_3binObs[i,k,j+1]:
                        obs_burst3bin[i,k,j]=16
                    elif cad_L2000_3binObs[i,k,j]==cad_L2000_3binObs[i,k,j+1]:
                        obs_burst3bin[i,k,j:j+2]=16
            else:
                if cad_L2000_3binObs[i,k,j-1]-cad_L2000_3binObs[i,k,j]==3:
                    obs_burst3bin[i,k,j:j+2]=16
                elif cad_L2000_3binObs[i,k,j]-cad_L2000_3binObs[i,k,j-1]==3:
                    obs_burst3bin[i,k,j-2:j]=16

num2000_3bin16=0
list2000_3bin16=[]
num2000_3bin40=0
list2000_3bin40=[]
num2000_3bin100=0
list2000_3bin100=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if obs_burst3bin[i,k,j]==100:
                num2000_3bin100+=1
            elif obs_burst3bin[i,k,j]==40:
                num2000_3bin40+=1
            elif obs_burst3bin[i,k,j]==16:
                num2000_3bin16+=1
        list2000_3bin16.append(num2000_3bin16)
        num2000_3bin16=0
        list2000_3bin40.append(num2000_3bin40)
        num2000_3bin40=0
        list2000_3bin100.append(num2000_3bin100)
        num2000_3bin100=0

num2000_3bin16_total=0
list2000_3bin16_total=[]
num2000_3bin40_total=0
list2000_3bin40_total=[]
num2000_3bin100_total=0
list2000_3bin100_total=[]
for i in range(run):
    for j in range(1,12):
        for k in range(cluster_size):
            if obs_burst3bin[i,k,j]==100 and obs_burst3bin[i,k,j-1]!=100:
                num2000_3bin100_total+=1
            elif obs_burst3bin[i,k,j-1]==100 and obs_burst3bin[i,k,j]!=100:
                num2000_3bin100_total+=1
            elif j==1 and obs_burst3bin[i,k,j-1]==40 and obs_burst3bin[i,k,j]!=40:
                num2000_3bin40_total+=1
            elif obs_burst3bin[i,k,j]==40 and obs_burst3bin[i,k,j-1]!=40:
                num2000_3bin40_total+=1
            elif j==1 and obs_burst3bin[i,k,j-1]==16 and obs_burst3bin[i,k,j]!=16:
                num2000_3bin16_total+=1
            elif obs_burst3bin[i,k,j]==16 and obs_burst3bin[i,k,j-1]!=16:
                num2000_3bin16_total+=1
    list2000_3bin16_total.append(num2000_3bin16_total)
    num2000_3bin16_total=0
    list2000_3bin40_total.append(num2000_3bin40_total)
    num2000_3bin40_total=0
    list2000_3bin100_total.append(num2000_3bin100_total)
    num2000_3bin100_total=0

# %% [markdown]
# ## 4 bins

# %%
L2000_4bin=np.load('/home/lee/data/2000stars_only/L2000_4.npy')

cluster_size=2000

cad_L2000_4binObs=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_L2000_4binObs[i,j,k]=L2000_4bin[i,j,t_list_cadence[k]]

obs_burst4bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==5:
                    obs_burst4bin[i,k,j-30:j]=100
            elif cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==5:
                    obs_burst4bin[i,k,j:j+30]=100

#40
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==4:
                    obs_burst4bin[i,k,j-1]=40
                elif cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==4:
                    if cad_L2000_4binObs[i,k,j]!=cad_L2000_4binObs[i,k,j+1]:
                        obs_burst4bin[i,k,j]=40
                    elif cad_L2000_4binObs[i,k,j]==cad_L2000_4binObs[i,k,j+1]:
                        obs_burst4bin[i,k,j:j+2]=40
            else:
                if cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==4:
                    obs_burst4bin[i,k,j-6:j]=40
                    obs_burst4bin[i,k,0]=0
                elif cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==4:
                    obs_burst4bin[i,k,j:j+6]=40

#16
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==3:
                    obs_burst4bin[i,k,j-1]=16
                elif cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==3:
                    if cad_L2000_4binObs[i,k,j]!=cad_L2000_4binObs[i,k,j+1]:
                        obs_burst4bin[i,k,j]=16
                    elif cad_L2000_4binObs[i,k,j]==cad_L2000_4binObs[i,k,j+1]:
                        obs_burst4bin[i,k,j:j+2]=16
            else:
                if cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==3:
                    obs_burst4bin[i,k,j:j+2]=16
                elif cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==3:
                    obs_burst4bin[i,k,j-2:j]=16

#3
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_4binObs[i,k,j]-cad_L2000_4binObs[i,k,j-1]==1.25:
                obs_burst4bin[i,k,j-1]=3
            elif cad_L2000_4binObs[i,k,j-1]-cad_L2000_4binObs[i,k,j]==1.25:
               obs_burst4bin[i,k,j]=3
                
num2000_4bin3=0
list2000_4bin3=[]
num2000_4bin16=0
list2000_4bin16=[]
num2000_4bin40=0
list2000_4bin40=[]
num2000_4bin100=0
list2000_4bin100=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if obs_burst4bin[i,k,j]==100:
                num2000_4bin100+=1
            elif obs_burst4bin[i,k,j]==40:
                num2000_4bin40+=1
            elif obs_burst4bin[i,k,j]==16:
                num2000_4bin16+=1
            elif obs_burst4bin[i,k,j]==3:
                num2000_4bin3+=1
        list2000_4bin3.append(num2000_4bin3)
        num2000_4bin3=0
        list2000_4bin16.append(num2000_4bin16)
        num2000_4bin16=0
        list2000_4bin40.append(num2000_4bin40)
        num2000_4bin40=0
        list2000_4bin100.append(num2000_4bin100)
        num2000_4bin100=0

num2000_4bin3_total=0
list2000_4bin3_total=[]
num2000_4bin16_total=0
list2000_4bin16_total=[]
num2000_4bin40_total=0
list2000_4bin40_total=[]
num2000_4bin100_total=0
list2000_4bin100_total=[]
for i in range(run):
    for j in range(1,12):
        for k in range(cluster_size):
            if obs_burst4bin[i,k,j]==100 and obs_burst4bin[i,k,j-1]!=100:
                num2000_4bin100_total+=1
            elif obs_burst4bin[i,k,j-1]==100 and obs_burst4bin[i,k,j]!=100:
                num2000_4bin100_total+=1
            elif j==1 and obs_burst4bin[i,k,j-1]==40 and obs_burst4bin[i,k,j]!=40:
                num2000_4bin40_total+=1
            elif obs_burst4bin[i,k,j]==40 and obs_burst4bin[i,k,j-1]!=40:
                num2000_4bin40_total+=1
            elif j==1 and obs_burst4bin[i,k,j-1]==16 and obs_burst4bin[i,k,j]!=16:
                num2000_4bin16_total+=1
            elif obs_burst4bin[i,k,j]==16 and obs_burst4bin[i,k,j-1]!=16:
                num2000_4bin16_total+=1
            elif j==1 and obs_burst4bin[i,k,j-1]==3 and obs_burst4bin[i,k,j]!=3:
                num2000_4bin3_total+=1
            elif obs_burst4bin[i,k,j]==3 and obs_burst4bin[i,k,j-1]!=3:
                num2000_4bin3_total+=1
    list2000_4bin3_total.append(num2000_4bin3_total)
    num2000_4bin3_total=0
    list2000_4bin16_total.append(num2000_4bin16_total)
    num2000_4bin16_total=0
    list2000_4bin40_total.append(num2000_4bin40_total)
    num2000_4bin40_total=0
    list2000_4bin100_total.append(num2000_4bin100_total)
    num2000_4bin100_total=0

# %% [markdown]
# ## 5 bins

# %%
L2000_5bin=np.load('/home/lee/data/2000stars_only/L2000_5.npy')

cluster_size=2000

cad_L2000_5binObs=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_L2000_5binObs[i,j,k]=L2000_5bin[i,j,t_list_cadence[k]]

obs_burst5bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==5:
                    obs_burst5bin[i,k,j-30:j]=100
            elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==5:
                    obs_burst5bin[i,k,j:j+30]=100

#40
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==4:
                    obs_burst5bin[i,k,j-1]=40
                elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==4:
                    if cad_L2000_5binObs[i,k,j]!=cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j]=40
                    elif cad_L2000_5binObs[i,k,j]==cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j:j+2]=40
            else:
                if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==4:
                    obs_burst5bin[i,k,j-6:j]=40
                    obs_burst5bin[i,k,0]=0
                elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==4:
                    obs_burst5bin[i,k,j:j+6]=40

#16
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==3:
                    obs_burst5bin[i,k,j-1]=16
                elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==3:
                    if cad_L2000_5binObs[i,k,j]!=cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j]=16
                    elif cad_L2000_5binObs[i,k,j]==cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j:j+2]=16
            else:
                if cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==3:
                    obs_burst5bin[i,k,j:j+2]=16
                elif cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==3:
                    obs_burst5bin[i,k,j-2:j]=16

#3
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==1.25:
                obs_burst5bin[i,k,j-1]=3
            elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==1.25:
               obs_burst5bin[i,k,j]=3

#6
for i in range(run):
    for k in range(cluster_size):
        for j in range(1,12):
            if j==1:
                if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==2:
                    obs_burst5bin[i,k,j-1]=6
                elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==2:
                    if cad_L2000_5binObs[i,k,j]!=cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j]=6
                    elif cad_L2000_5binObs[i,k,j]==cad_L2000_5binObs[i,k,j+1]:
                        obs_burst5bin[i,k,j:j+2]=6
            else:
                if cad_L2000_5binObs[i,k,j]-cad_L2000_5binObs[i,k,j-1]==2:
                    obs_burst5bin[i,k,j-6:j]=6
                    obs_burst5bin[i,k,0]=0
                elif cad_L2000_5binObs[i,k,j-1]-cad_L2000_5binObs[i,k,j]==2:
                    obs_burst5bin[i,k,j:j+6]=6
                
num2000_5bin6=0
list2000_5bin6=[]
num2000_5bin3=0
list2000_5bin3=[]
num2000_5bin16=0
list2000_5bin16=[]
num2000_5bin40=0
list2000_5bin40=[]
num2000_5bin100=0
list2000_5bin100=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if obs_burst5bin[i,k,j]==100:
                num2000_5bin100+=1
            elif obs_burst5bin[i,k,j]==40:
                num2000_5bin40+=1
            elif obs_burst5bin[i,k,j]==16:
                num2000_5bin16+=1
            elif obs_burst5bin[i,k,j]==3:
                num2000_5bin3+=1
            elif obs_burst5bin[i,k,j]==6:
                num2000_5bin6+=1
        list2000_5bin6.append(num2000_5bin6)
        num2000_5bin6=0
        list2000_5bin3.append(num2000_5bin3)
        num2000_5bin3=0
        list2000_5bin16.append(num2000_5bin16)
        num2000_5bin16=0
        list2000_5bin40.append(num2000_5bin40)
        num2000_5bin40=0
        list2000_5bin100.append(num2000_5bin100)
        num2000_5bin100=0

num2000_5bin6_total=0
list2000_5bin6_total=[]
num2000_5bin3_total=0
list2000_5bin3_total=[]
num2000_5bin16_total=0
list2000_5bin16_total=[]
num2000_5bin40_total=0
list2000_5bin40_total=[]
num2000_5bin100_total=0
list2000_5bin100_total=[]
for i in range(run):
    for j in range(1,12):
        for k in range(cluster_size):
            if obs_burst5bin[i,k,j]==100 and obs_burst5bin[i,k,j-1]!=100:
                num2000_5bin100_total+=1
            elif obs_burst5bin[i,k,j-1]==100 and obs_burst5bin[i,k,j]!=100:
                num2000_5bin100_total+=1
            elif j==1 and obs_burst5bin[i,k,j-1]==40 and obs_burst5bin[i,k,j]!=40:
                num2000_5bin40_total+=1
            elif obs_burst5bin[i,k,j]==40 and obs_burst5bin[i,k,j-1]!=40:
                num2000_5bin40_total+=1
            elif j==1 and obs_burst5bin[i,k,j-1]==16 and obs_burst5bin[i,k,j]!=16:
                num2000_5bin16_total+=1
            elif obs_burst5bin[i,k,j]==16 and obs_burst5bin[i,k,j-1]!=16:
                num2000_5bin16_total+=1
            elif j==1 and obs_burst5bin[i,k,j-1]==3 and obs_burst5bin[i,k,j]!=3:
                num2000_5bin3_total+=1
            elif obs_burst5bin[i,k,j]==3 and obs_burst5bin[i,k,j-1]!=3:
                num2000_5bin3_total+=1
            elif j==1 and obs_burst5bin[i,k,j-1]==6 and obs_burst5bin[i,k,j]!=6:
                num2000_5bin6_total+=1
            elif obs_burst5bin[i,k,j]==6 and obs_burst5bin[i,k,j-1]!=6:
                num2000_5bin6_total+=1
    list2000_5bin6_total.append(num2000_5bin6_total)
    num2000_5bin6_total=0
    list2000_5bin3_total.append(num2000_5bin3_total)
    num2000_5bin3_total=0
    list2000_5bin16_total.append(num2000_5bin16_total)
    num2000_5bin16_total=0
    list2000_5bin40_total.append(num2000_5bin40_total)
    num2000_5bin40_total=0
    list2000_5bin100_total.append(num2000_5bin100_total)
    num2000_5bin100_total=0

# %% [markdown]
# # missed and statistics

# %%
print('Obs mean=',np.mean(list2000_3bin40_total))
print('Obs std=',np.std(list2000_3bin40_total))

print('True mean=',np.mean(num2000_3bin40_list))
print('True std=',np.std(num2000_3bin40_list))

print('Percent Detected=',np.mean(list2000_3bin40_total)/np.mean(num2000_3bin40_list)*100)
# Out:
# Obs mean= 76.9
# Obs std= 10.218121158021175
# True mean= 227.28
# True std= 17.40234466961277
# Percent Detected= 33.834917282646956
