# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import csv

run=50
t=300
cadence=26
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*cadence) for i in t_list_years]

# %% [markdown]
# ## Number of bursts happening at any given time
# This is the number of bursts that are physically happening at any given time during the simulation, specifically
# the times at which we want to observe

# %%
values50table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values50_6x')
burst_total50_2week=values50table_2week['burst_total'] 
burst_fraction50_2week=values50table_2week['burst_number'] 

values100table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values100_6x')
burst_total100_2week=values100table_2week['burst_total'] 
burst_fraction100_2week=values100table_2week['burst_number'] 

values500table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values500_6x')
burst_total500_2week=values500table_2week['burst_total'] 
burst_fraction500_2week=values500table_2week['burst_number'] 

values1000table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values1000_6x')
burst_total1000_2week=values1000table_2week['burst_total'] 
burst_fraction1000_2week=values1000table_2week['burst_number'] 

values2000table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values2000_6x')
burst_total2000_2week=values2000table_2week['burst_total'] 
burst_fraction2000_2week=values2000table_2week['burst_number'] 

values5000table_2week=ascii.read('/home/lee/data/cluster_size_change/6x_burst/values5000_6x')
burst_total5000_2week=values5000table_2week['burst_total'] 
burst_fraction5000_2week=values5000table_2week['burst_number']

# %%
cadence_num_bursts50_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts50_2week.append(burst_fraction50_2week[i][j])
        
cadence_num_bursts100_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts100_2week.append(burst_fraction100_2week[i][j])
        
cadence_num_bursts500_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts500_2week.append(burst_fraction500_2week[i][j])
        
cadence_num_bursts1000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_2week.append(burst_fraction1000_2week[i][j])
        
cadence_num_bursts2000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts2000_2week.append(burst_fraction2000_2week[i][j])

cadence_num_bursts5000_2week=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts5000_2week.append(burst_fraction5000_2week[i][j])

print(cadence_num_bursts5000_2week)
# Out:
# [719, 720, 723, 693, 682, 697, 684, 683, 681, 711, 729, 711, 735, 705, 703, 697, 687, 707, 721, 733, 710, 715, 712, 691, 682, 751, 777, 773, 758, 747, 732, 712, 692, 689, 711, 711, 714, 704, 713, 729, 720, 745, 748, 736, 714, 710, 713, 683, 682, 735, 742, 715, 733, 725, 727, 701, 702, 707, 691, 704, 768, 666, 687, 691, 710, 708, 710, 694, 650, 652, 676, 682, 742, 726, 714, 714, 732, 717, 691, 691, 674, 657, 662, 678, 708, 725, 741, 711, 683, 699, 706, 689, 662, 683, 710, 708, 732, 716, 733, 743, 716, 728, 719, 709, 686, 682, 700, 713, 705, 744, 732, 753, 739, 722, 706, 676, 709, 703, 698, 699, 675, 725, 727, 733, 725, 749, 727, 727, 727, 697, 683, 653, 714, 683, 677, 670, 685, 714, 738, 735, 724, 719, 736, 706, 707, 724, 702, 727, 695, 699, 719, 727, 743, 740, 750, 756, 732, 697, 697, 702, 700, 713, 741, 746, 737, 739, 716, 714, 722, 684, 717, 700, 696, 681, 669, 678, 657, 682, 702, 709, 717, 705, 733, 715, 725, 733, 740, 731, 714, 689, 698, 694, 719, 691, 693, 714, 729, 727, 745, 760, 774, 777, 757, 757, 701, 695, 725, 750, 749, 736, 752, 753, 769, 744, 761, 760, 671, 741, 728, 730, 737, 710, 710, 716, 716, 720, 704, 708, 727, 728, 751, 706, 706, 701, 682, 716, 687, 705, 712, 709, 669, 734, 736, 719, 747, 777, 769, 771, 790, 770, 739, 706, 734, 740, 728, 708, 716, 706, 692, 662, 675, 675, 678, 707, 697, 704, 708, 714, 716, 721, 703, 692, 697, 712, 695, 680, 665, 672, 698, 701, 723, 710, 708, 725, 731, 732, 724, 712, 715, 701, 702, 698, 714, 719, 727, 720, 744, 746, 722, 717, 688, 779, 768, 770, 772, 759, 748, 721, 729, 718, 696, 713, 680, 713, 710, 683, 665, 680, 690, 695, 718, 728, 725, 729, 652, 708, 713, 704, 730, 725, 718, 721, 716, 712, 674, 679, 697, 696, 700, 687, 672, 682, 705, 691, 685, 702, 722, 727, 703, 705, 717, 724, 697, 720, 700, 702, 687, 698, 712, 715, 714, 703, 720, 702, 732, 703, 706, 685, 699, 684, 682, 711, 679, 739, 715, 745, 726, 715, 727, 723, 737, 694, 702, 719, 727, 703, 720, 730, 728, 698, 714, 732, 718, 699, 725, 739, 713, 708, 701, 704, 703, 675, 673, 681, 693, 708, 700, 714, 708, 749, 746, 734, 740, 732, 725, 696, 718, 721, 714, 727, 695, 722, 722, 706, 716, 716, 695, 696, 694, 718, 690, 702, 689, 699, 699, 717, 704, 719, 727, 723, 724, 701, 717, 704, 689, 701, 708, 708, 725, 730, 728, 734, 724, 726, 715, 702, 753, 718, 730, 728, 707, 710, 694, 693, 673, 675, 699, 702, 679, 713, 727, 723, 729, 726, 750, 752, 732, 730, 752, 740, 712, 727, 739, 726, 724, 720, 700, 694, 687, 695, 708, 710, 695, 718, 729, 714, 715, 729, 733, 719, 684, 695, 701, 697, 712, 719, 719, 728, 713, 693, 709, 695, 686, 681, 696, 728, 669, 723, 726, 758, 769, 743, 753, 753, 724, 715, 707, 715, 668, 659, 667, 709, 682, 693, 715, 738, 713, 711, 705, 725, 717, 675, 677, 673, 664, 679, 700, 725, 721, 708, 710, 682, 725, 719, 723, 734, 718, 730, 759, 764, 747, 737, 723, 706, 692, 704, 705, 699, 689, 708, 725, 724, 735, 733, 734, 720, 719, 722, 705, 717, 696, 707, 697, 708, 702, 692, 710, 680, 719, 740, 741, 753, 753, 763, 753, 785, 758, 742, 750, 744]

# %%
data_num_2week=[cadence_num_bursts50_2week,cadence_num_bursts100_2week,cadence_num_bursts500_2week,\
                cadence_num_bursts1000_2week,cadence_num_bursts2000_2week,cadence_num_bursts5000_2week]

labels=[50,100,500,1000,2000,5000]
fig,ax=plt.subplots()
fig.set_size_inches(9,8)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'
ax.violinplot(data_num_2week,vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
plt.xticks([1,2,3,4,5,6,],['50','100','500','1000','2000','5000'])
ax.set_xlabel('Number of Stars in Cluster',fontsize=13)
ax.set_ylabel('Number of Bursts',fontsize=13)
ax.set_title('Number of 6x Burst for Different Cluster Sizes (Any Time)',fontsize=15)
plt.plot()
plt.savefig('/home/lee/research/figs/SizeChange/violinplots/number/6x_burst/violin_plot_50run_6x_normal.jpeg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Number of bursts that are happening during an entire observing program
# This is the number of bursts physically happening during our observing program, taking only the data from the dates
# in which we would like to observe the cluster

# %% [markdown]
# ## 50 stars

# %%
burst50=np.load('/home/lee/data/cluster_size_change/6x_burst/burst50_6x.npy')
L50=np.load('/home/lee/data/cluster_size_change/6x_burst/L50_6x.npy')
C50=np.load('/home/lee/data/cluster_size_change/6x_burst/C50_6x.npy')

# %%
cluster_size50=50
cad_C50=np.zeros((run,cluster_size50,12))
for i in range(run):
    for j in range(cluster_size50):
        for k in range(len(t_list_cadence)):
                cad_C50[i,j,k]=C50[i,j,t_list_cadence[k]]

# %%
print(np.shape(cad_C50))
# Out:
# (50, 50, 12)

# %%
num50=0
num50_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size50):
            if cad_C50[i,k,j]==2 and cad_C50[i,k,j]!=cad_C50[i,k,j-1]:
                num50+=1
    num50_list.append(num50)
    num50=0

# %%
print(num50_list)
# Out:
# [27, 21, 28, 23, 20, 21, 26, 23, 22, 29, 25, 19, 24, 21, 29, 25, 24, 36, 29, 20, 28, 18, 18, 16, 29, 19, 20, 29, 16, 26, 25, 20, 21, 28, 18, 27, 24, 22, 31, 28, 20, 23, 30, 19, 23, 25, 27, 27, 19, 29]

# %% [markdown]
# ## 100 stars

# %%
burst100=np.load('/home/lee/data/cluster_size_change/6x_burst/burst100_6x.npy')
L100=np.load('/home/lee/data/cluster_size_change/6x_burst/L100_6x.npy')
C100=np.load('/home/lee/data/cluster_size_change/6x_burst/C100_6x.npy')

# %%
cluster_size100=100
cad_C100=np.zeros((run,cluster_size100,12))
for i in range(run):
    for j in range(cluster_size100):
        for k in range(len(t_list_cadence)):
                cad_C100[i,j,k]=C100[i,j,t_list_cadence[k]]

# %%
num100=0
num100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size100):
            if cad_C100[i,k,j]==2 and cad_C100[i,k,j]!=cad_C100[i,k,j-1]:
                num100+=1
    num100_list.append(num100)
    num100=0

# %%
print(num100_list)
# Out:
# [50, 37, 56, 50, 46, 47, 47, 51, 44, 57, 53, 49, 61, 48, 47, 42, 48, 58, 55, 49, 43, 55, 43, 48, 52, 53, 45, 39, 53, 44, 46, 55, 45, 42, 48, 42, 39, 44, 50, 54, 41, 48, 50, 52, 42, 49, 55, 39, 58, 43]

# %% [markdown]
# ## 500 stars

# %%
burst500=np.load('/home/lee/data/cluster_size_change/6x_burst/burst500_6x.npy')
L500=np.load('/home/lee/data/cluster_size_change/6x_burst/L500_6x.npy')
C500=np.load('/home/lee/data/cluster_size_change/6x_burst/C500_6x.npy')

# %%
cluster_size500=500
cad_C500=np.zeros((run,cluster_size500,12))
for i in range(run):
    for j in range(cluster_size500):
        for k in range(len(t_list_cadence)):
                cad_C500[i,j,k]=C500[i,j,t_list_cadence[k]]

# %%
num500=0
num500_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size500):
            if cad_C500[i,k,j]==2 and cad_C500[i,k,j]!=cad_C500[i,k,j-1]:
                num500+=1
    num500_list.append(num500)
    num500=0

# %%
print(num500_list)
# Out:
# [246, 228, 238, 239, 222, 248, 211, 260, 241, 237, 224, 244, 246, 263, 212, 228, 233, 253, 229, 254, 250, 234, 237, 238, 244, 252, 261, 234, 236, 260, 279, 252, 242, 235, 213, 231, 226, 256, 252, 229, 245, 248, 247, 236, 248, 222, 245, 216, 251, 234]

# %% [markdown]
# ## 1000 stars

# %%
burst1000=np.load('/home/lee/data/cluster_size_change/6x_burst/burst1000_6x.npy')
L1000=np.load('/home/lee/data/cluster_size_change/6x_burst/L1000_6x.npy')
C1000=np.load('/home/lee/data/cluster_size_change/6x_burst/C1000_6x.npy')

# %%
cluster_size1000=1000
cad_C1000=np.zeros((run,cluster_size1000,12))
for i in range(run):
    for j in range(cluster_size1000):
        for k in range(len(t_list_cadence)):
                cad_C1000[i,j,k]=C1000[i,j,t_list_cadence[k]]

# %%
num1000=0
num1000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size1000):
            if cad_C1000[i,k,j]==2 and cad_C1000[i,k,j]!=cad_C1000[i,k,j-1]:
                num1000+=1
    num1000_list.append(num1000)
    num1000=0

# %%
print(num1000_list)
# Out:
# [479, 479, 479, 517, 461, 455, 486, 468, 480, 483, 486, 493, 504, 479, 499, 469, 487, 489, 464, 495, 480, 466, 479, 487, 474, 462, 474, 505, 477, 466, 468, 477, 476, 501, 494, 499, 458, 471, 465, 487, 489, 482, 499, 489, 483, 472, 456, 465, 509, 535]

# %% [markdown]
# ## 2000 stars

# %%
burst2000=np.load('/home/lee/data/cluster_size_change/6x_burst/burst2000_6x.npy')
L2000=np.load('/home/lee/data/cluster_size_change/6x_burst/L2000_6x.npy')
C2000=np.load('/home/lee/data/cluster_size_change/6x_burst/C2000_6x.npy')

# %%
cluster_size2000=2000
cad_C2000=np.zeros((run,cluster_size2000,12))
for i in range(run):
    for j in range(cluster_size2000):
        for k in range(len(t_list_cadence)):
                cad_C2000[i,j,k]=C2000[i,j,t_list_cadence[k]]

# %%
num2000=0
num2000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size2000):
            if cad_C2000[i,k,j]==2 and cad_C2000[i,k,j]!=cad_C2000[i,k,j-1]:
                num2000+=1
    num2000_list.append(num2000)
    num2000=0

# %%
print(num2000_list)
# Out:
# [955, 974, 1007, 964, 948, 1002, 940, 969, 983, 991, 941, 955, 962, 924, 970, 960, 932, 991, 935, 987, 992, 987, 944, 950, 953, 952, 966, 938, 970, 957, 951, 958, 920, 963, 992, 950, 952, 1007, 979, 913, 950, 1000, 978, 939, 1024, 987, 988, 972, 977, 968]

# %% [markdown]
# ## 5000 stars

# %%
burst5000=np.load('/home/lee/data/cluster_size_change/6x_burst/burst5000_6x.npy')
L5000=np.load('/home/lee/data/cluster_size_change/6x_burst/L5000_6x.npy')
C5000=np.load('/home/lee/data/cluster_size_change/6x_burst/C5000_6x.npy')

# %%
cluster_size5000=5000
cad_C5000=np.zeros((run,cluster_size5000,12))
for i in range(run):
    for j in range(cluster_size5000):
        for k in range(len(t_list_cadence)):
                cad_C5000[i,j,k]=C5000[i,j,t_list_cadence[k]]

# %%
num5000=0
num5000_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size5000):
            if cad_C5000[i,k,j]==2 and cad_C5000[i,k,j]!=cad_C5000[i,k,j-1]:
                num5000+=1
    num5000_list.append(num5000)
    num5000=0

# %%
print(num5000_list)
# Out:
# [2379, 2361, 2422, 2402, 2391, 2357, 2404, 2383, 2407, 2385, 2351, 2372, 2440, 2409, 2352, 2387, 2431, 2420, 2388, 2398, 2401, 2385, 2387, 2318, 2414, 2454, 2339, 2327, 2352, 2408, 2380, 2414, 2419, 2362, 2447, 2378, 2389, 2365, 2430, 2409, 2416, 2394, 2392, 2399, 2326, 2351, 2417, 2407, 2385, 2492]

# %% [markdown]
# ## log scale

# %%
num_new50=[]
num_new100=[]
num_new500=[]
num_new1000=[]
num_new2000=[]
num_new5000=[]
for i in range(len(num50_list)):
    if num50_list[i]!=0:
        num_new50.append(num50_list[i])
        
for i in range(len(num100_list)):
    if num100_list[i]!=0:
        num_new100.append(num100_list[i])
        
for i in range(len(num500_list)):
    if num500_list[i]!=0:
        num_new500.append(num500_list[i])
        
for i in range(len(num1000_list)):
    if num1000_list[i]!=0:
        num_new1000.append(num1000_list[i])
        
for i in range(len(num2000_list)):
    if num2000_list[i]!=0:
        num_new2000.append(num2000_list[i])
        
for i in range(len(num5000_list)):
    if num5000_list[i]!=0:
        num_new5000.append(num5000_list[i])

# %%
data_num=[num_new50,num_new100,num_new500,num_new1000,num_new2000,num_new5000]
print(data_num)
# Out:
# [[27, 21, 28, 23, 20, 21, 26, 23, 22, 29, 25, 19, 24, 21, 29, 25, 24, 36, 29, 20, 28, 18, 18, 16, 29, 19, 20, 29, 16, 26, 25, 20, 21, 28, 18, 27, 24, 22, 31, 28, 20, 23, 30, 19, 23, 25, 27, 27, 19, 29], [50, 37, 56, 50, 46, 47, 47, 51, 44, 57, 53, 49, 61, 48, 47, 42, 48, 58, 55, 49, 43, 55, 43, 48, 52, 53, 45, 39, 53, 44, 46, 55, 45, 42, 48, 42, 39, 44, 50, 54, 41, 48, 50, 52, 42, 49, 55, 39, 58, 43], [246, 228, 238, 239, 222, 248, 211, 260, 241, 237, 224, 244, 246, 263, 212, 228, 233, 253, 229, 254, 250, 234, 237, 238, 244, 252, 261, 234, 236, 260, 279, 252, 242, 235, 213, 231, 226, 256, 252, 229, 245, 248, 247, 236, 248, 222, 245, 216, 251, 234], [479, 479, 479, 517, 461, 455, 486, 468, 480, 483, 486, 493, 504, 479, 499, 469, 487, 489, 464, 495, 480, 466, 479, 487, 474, 462, 474, 505, 477, 466, 468, 477, 476, 501, 494, 499, 458, 471, 465, 487, 489, 482, 499, 489, 483, 472, 456, 465, 509, 535], [955, 974, 1007, 964, 948, 1002, 940, 969, 983, 991, 941, 955, 962, 924, 970, 960, 932, 991, 935, 987, 992, 987, 944, 950, 953, 952, 966, 938, 970, 957, 951, 958, 920, 963, 992, 950, 952, 1007, 979, 913, 950, 1000, 978, 939, 1024, 987, 988, 972, 977, 968], [2379, 2361, 2422, 2402, 2391, 2357, 2404, 2383, 2407, 2385, 2351, 2372, 2440, 2409, 2352, 2387, 2431, 2420, 2388, 2398, 2401, 2385, 2387, 2318, 2414, 2454, 2339, 2327, 2352, 2408, 2380, 2414, 2419, 2362, 2447, 2378, 2389, 2365, 2430, 2409, 2416, 2394, 2392, 2399, 2326, 2351, 2417, 2407, 2385, 2492]]

# %%
labels=[50,100,500,1000,2000,5000]
fig,ax=plt.subplots()
fig.set_size_inches(9,8)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'
ax.violinplot(data_num,vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
plt.xticks([1,2,3,4,5,6,],['50','100','500','1000','2000','5000'])
ax.set_xlabel('Number of Stars in Cluster',fontsize=13)
ax.set_ylabel('Number of Bursts',fontsize=13)
ax.set_title('Number of 6x Bursts for Different Cluster Sizes (Entire Observing Program)',fontsize=14)
plt.plot()
plt.savefig('/home/lee/research/figs/SizeChange/violinplots/number/6x_burst/observing_run_6x.jpeg',dpi=300,bbox_inches='tight')
