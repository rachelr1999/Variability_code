# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import csv

# %%
burst2000_1bin=np.load('/home/lee/data/2000stars_only/burst2000_1.npy')
L2000_1bin=np.load('/home/lee/data/2000stars_only/L2000_1.npy')
C2000_1bin=np.load('/home/lee/data/2000stars_only/C2000_1.npy')

# %%
print(np.shape(L2000_1bin))
# Out:
# (50, 2000, 7800)

# %%
run_num=[]
star_num=[]
for i in range(50):
    for j in range(2000):
        for k in range(7800):
            if L2000_1bin[i,j,k]-L2000_1bin[i,j,k-1]==5:
                run_num.append(i)
                star_num.append(j)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 for j in range(2000):
#       5     for k in range(7800):
# ----> 6         if L2000_1bin[i,j,k]-L2000_1bin[i,j,k-1]==5:
#       7             run_num.append(i)
#       8             star_num.append(j)
#
# KeyboardInterrupt:

# %%
print(np.shape(run_num))

# %%
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*26) for i in t_list_years]

# %%
time=np.linspace(0,300,7800)
plt.plot(time,L2000_1bin[run_num[18],star_num[18],:],color='black')
plt.xlim(200,225)

# %%
time=np.linspace(0,300,7800)

fig,(ax1,ax2,ax3,ax4)=plt.subplots(4,1,sharex='col')
fig.set_size_inches(14,14)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

ax1.plot(time,L2000_1bin[run_num[1],star_num[1],:],color='black')
ax2.plot(time,L2000_1bin[run_num[9],star_num[9],:],color='black')
ax3.plot(time,L2000_1bin[run_num[18],star_num[18],:],color='black')
ax4.plot(time,L2000_1bin[run_num[38],star_num[38],:],color='black')

ax1.set_xlim(198,227)

for i in range(len(t_list_years)):
    ax1.axvline(t_list_years[i],color='red',alpha=0.5)
    ax2.axvline(t_list_years[i],color='red',alpha=0.5)
    ax3.axvline(t_list_years[i],color='red',alpha=0.5)
    ax4.axvline(t_list_years[i],color='red',alpha=0.5)

fig.tight_layout()
ax1.tick_params(axis='both',right=False,top=False,which='both')
ax1.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax2.locator_params(axis='y',nbins=6)
ax2.tick_params(axis='both',right=False,top=False,which='both')
ax2.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax3.locator_params(axis='y',nbins=6)
ax3.tick_params(axis='both',right=False,top=False,which='both')
ax3.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax4.tick_params(axis='both',right=False,top=False,which='both')
ax4.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)

ax1.invert_yaxis()
ax2.invert_yaxis()
ax3.invert_yaxis()
ax4.invert_yaxis()

ax5=fig.add_subplot(111,frameon=False)
#plt.tick_params(labelcolor='none',top='off',bottom='off',left='off',right='off',which='both',axis='both')
plt.minorticks_off()
plt.grid(False)
ax5.set_yticks([])
ax5.set_xticks([])
ax5.set_ylabel(r'Magnitude',fontsize=20,labelpad=50)
ax5.set_xlabel('Time (yrs)',fontsize=20,labelpad=30)
ax5.set_title('Example light curves of our simulated data (1 bin)',fontsize=25)

#plt.savefig('/Users/rachellee/Desktop/research/figs/light_curves/example_light_curves_1bin.jpeg',dpi=300,bbox_inches='tight')

# %%
burst2000_5bin=np.load('/home/lee/data/2000stars_only/burst2000_5.npy')
L2000_5bin=np.load('/home/lee/data/2000stars_only/L2000_5.npy')
C2000_5bin=np.load('/home/lee/data/2000stars_only/C2000_5.npy')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 burst2000_5bin=np.load('/home/lee/data/2000stars_only/burst2000_5.npy')
# ----> 2 L2000_5bin=np.load('/home/lee/data/2000stars_only/L2000_5.npy')
#       3 C2000_5bin=np.load('/home/lee/data/2000stars_only/C2000_5.npy')
#
# File /mnt/data0/local/casa-6.5.5-21-py3.8/lib/py/lib/python3.8/site-packages/numpy/lib/npyio.py:432, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     429         return format.open_memmap(file, mode=mmap_mode,
#     430                                   max_header_size=max_header_size)
#     431     else:
# --> 432         return format.read_array(fid, allow_pickle=allow_pickle,
#     433                                  pickle_kwargs=pickle_kwargs,
#     434                                  max_header_size=max_header_size)
#     435 else:
# ...

# %%
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*26) for i in t_list_years]

# %%
run_num5=[]
star_num5=[]
for i in range(50):
    for j in range(2000):
        for k in range(7800):
            if L2000_5bin[i,j,k]-L2000_5bin[i,j,k-1]==5:
                run_num5.append(i)
                star_num5.append(j)

# %%
run_num4=[]
star_num4=[]
for i in range(50):
    for j in range(2000):
        for k in range(7800):
            if L2000_5bin[i,j,k]-L2000_5bin[i,j,k-1]==4:
                run_num4.append(i)
                star_num4.append(j)

# %%
time=np.linspace(0,300,7800)
plt.plot(time,L2000_5bin[run_num5[0],star_num5[0],:],color='black')
plt.xlim(198,227)

# %%
time=np.linspace(0,300,7800)
plt.plot(time,L2000_5bin[run_num5[0],star_num5[0],:],color='black')
plt.xlim(198,227)

# %%
#### time=np.linspace(0,300,7800)

fig,(ax1,ax2,ax3,ax4)=plt.subplots(4,1,sharex='col')
fig.set_size_inches(8,10)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='FreeSerif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

ax1.plot(time,L2000_5bin[run_num5[0],star_num5[0],:],color='black')
ax2.plot(time,L2000_5bin[run_num5[18],star_num5[18],:],color='black')
ax3.plot(time,L2000_5bin[run_num5[48],star_num5[48],:],color='black')
ax4.plot(time,L2000_5bin[run_num4[9],star_num4[9],:],color='black')

ax1.set_xlim(198,227)

for i in range(len(t_list_years)):
    ax1.axvline(t_list_years[i],color='red',alpha=0.5)
    ax2.axvline(t_list_years[i],color='red',alpha=0.5)
    ax3.axvline(t_list_years[i],color='red',alpha=0.5)
    ax4.axvline(t_list_years[i],color='red',alpha=0.5)

fig.tight_layout()
ax1.tick_params(axis='both',right=False,top=False,which='both')
ax1.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax2.locator_params(axis='y',nbins=6)
ax2.tick_params(axis='both',right=False,top=False,which='both')
ax2.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax3.locator_params(axis='y',nbins=6)
ax3.tick_params(axis='both',right=False,top=False,which='both')
ax3.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)
ax4.tick_params(axis='both',right=False,top=False,which='both')
ax4.tick_params(axis='both',which='major', length=5, width=1, direction='in',labelsize=15)

ax1.invert_yaxis()
ax2.invert_yaxis()
ax3.invert_yaxis()
ax4.invert_yaxis()

ax5=fig.add_subplot(111,frameon=False)
#plt.tick_params(labelcolor='none',top='off',bottom='off',left='off',right='off',which='both',axis='both')
plt.minorticks_off()
plt.grid(False)
ax5.set_yticks([])
ax5.set_xticks([])
ax5.set_ylabel(r'Magnitude',fontsize=20,labelpad=40)
ax5.set_xlabel('Time (yrs)',fontsize=20,labelpad=30)
ax5.set_title('Example light curves of our simulated data',fontsize=25)

plt.savefig('/home/lee/research/figs/light_curves/example_light_curves_5bin.jpeg',dpi=300,bbox_inches='tight')

# %%
print(L2000_5bin[0,95,0:10])
# Out:
# [-1.64741211  0.          0.         -1.64741211 -2.89741211 -2.89741211
#  -1.64741211 -1.64741211  0.         -1.64741211]

# %%
print(C2000_5bin[0,95,0:10])
# Out:
# [0. 0. 0. 0. 3. 3. 0. 0. 0. 0.]

# %%
t0=np.sum(X5)
print(t0)
# Out:
# 0.10674408217954444

# %%
A6=np.array([[1-t100,-t100,-t100,-t100,-t100,-t100],\
             [-t40,1-t40,-t40,-t40,-t40,-t40],\
             [-t16,-t16,1-t16,-t16,-t16,-t16],\
             [-t6,-t6,-t6,1-t6,-t6,-t6],\
             [-t3,-t3,-t3,-t3,1-t3,-t3],\
             [1+t0,1+t0,1+t0,1+t0,1+t0,t0]])
B6=np.array([0,0,0,0,0,1])
X6=np.linalg.inv(A6).dot(B6)
print(X6)
# Out:
# [0.0083682  0.0209205  0.05230126 0.13947001 0.27894003 4.18410042]

# %%
burst2000_4bin=np.load('/Users/rachellee/Downloads/data/2000stars_only/burst2000_4.npy')
L2000_4bin=np.load('/Users/rachellee/Downloads/data/2000stars_only/L2000_4.npy')
C2000_4bin=np.load('/Users/rachellee/Downloads/data/2000stars_only/C2000_4.npy')

# %%
run_num4=[]
star_num4=[]
for i in range(50):
    for j in range(2000):
        for k in range(7800):
            if L2000_4bin[i,j,k]-L2000_4bin[i,j,k-1]==5:
                run_num4.append(i)
                star_num4.append(j)

# %%
time=np.linspace(0,300,7800)
plt.plot(time,L2000_4bin[run_num4[10],star_num4[10],:],color='black')
plt.xlim(-1,10)
# Out:
# (-1.0, 10.0)
