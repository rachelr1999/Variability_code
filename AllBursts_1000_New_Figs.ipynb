# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import numpy as np
from astropy.io import ascii
from astropy.table import Table
import csv

run=50
t=300
cadence=26
t_list_years=[200,220,220.5,221,221.5,222,222.5,223,223.5,224,224.5,225]
t_list_cadence=[int(i*cadence) for i in t_list_years]

# %% [markdown]
# ## 1 bin

# %%
values1000_1bin=ascii.read('/Users/rachellee/Downloads/data/1000stars_only/values1000_1bin_2week') 
burst_total1000_1=values1000_1bin['burst_total']
burst_num1000_1=values1000_1bin['burst_number']

burst1000_1bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/burst1000_1.npy')
L1000_1bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/L1000_1.npy')
C1000_1bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/C1000_1.npy')

# %%
cadence_num_bursts1000_1=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_1.append(burst_num1000_1[i][j])

# %%
cadence_new1=[]
for i in range(len(cadence_num_bursts1000_1)):
    if cadence_num_bursts1000_1[i]!=0:
        cadence_new1.append(cadence_num_bursts1000_1[i])

data_1bin1000_log=[cadence_new1]

# %%
print(np.shape(cadence_new1))
# Out:
# (600,)

# %% [markdown]
# ## 2 bin

# %%
values1000_2bin=ascii.read('/Users/rachellee/Downloads/data/1000stars_only/values1000_2bin_2week') 
burst_total1000_2=values1000_2bin['burst_total']
burst_total1000_2_40=values1000_2bin['burst_total40']
burst_total1000_2_100=values1000_2bin['burst_total100']
burst_num1000_2_40=values1000_2bin['burst_num40']
burst_num1000_2_100=values1000_2bin['burst_num100']

burst1000_2bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/burst1000_2.npy')
L1000_2bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/L1000_2.npy')
C1000_2bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/C1000_2.npy')

# %%
cadence_num_bursts1000_2_40=[]
cadence_num_bursts1000_2_100=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_2_40.append(burst_num1000_2_40[i][j])
        cadence_num_bursts1000_2_100.append(burst_num1000_2_100[i][j])

# %%
cadence_new2_40=[]
cadence_new2_100=[]
for i in range(len(cadence_num_bursts1000_2_40)):
    if cadence_num_bursts1000_2_40[i]!=0:
        cadence_new2_40.append(cadence_num_bursts1000_2_40[i])
        
for i in range(len(cadence_num_bursts1000_2_100)):
    if cadence_num_bursts1000_2_100[i]!=0:
        cadence_new2_100.append(cadence_num_bursts1000_2_100[i])

data_2bin1000_log=[cadence_new2_100,cadence_new2_40]

# %% [markdown]
# ## 3 bin

# %%
values1000_3bin=ascii.read('/Users/rachellee/Downloads/data/1000stars_only/values1000_3bin_2week') 
burst_total1000_3=values1000_3bin['burst_total']
burst_total1000_3_16=values1000_3bin['burst_total16']
burst_total1000_3_40=values1000_3bin['burst_total40']
burst_total1000_3_100=values1000_3bin['burst_total100']
burst_num1000_3_16=values1000_3bin['burst_num16']
burst_num1000_3_40=values1000_3bin['burst_num40']
burst_num1000_3_100=values1000_3bin['burst_num100']

burst1000_3bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/burst1000_3.npy')
L1000_3bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/L1000_3.npy')
C1000_3bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/C1000_3.npy')

# %%
cadence_num_bursts1000_3_16=[]
cadence_num_bursts1000_3_40=[]
cadence_num_bursts1000_3_100=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_3_16.append(burst_num1000_3_16[i][j])
        cadence_num_bursts1000_3_40.append(burst_num1000_3_40[i][j])
        cadence_num_bursts1000_3_100.append(burst_num1000_3_100[i][j])

# %%
cadence_new3_16=[]
cadence_new3_40=[]
cadence_new3_100=[]
for i in range(len(cadence_num_bursts1000_3_16)):
    if cadence_num_bursts1000_3_16[i]!=0:
        cadence_new3_16.append(cadence_num_bursts1000_3_16[i])

for i in range(len(cadence_num_bursts1000_3_40)):
    if cadence_num_bursts1000_3_40[i]!=0:
        cadence_new3_40.append(cadence_num_bursts1000_3_40[i])
        
for i in range(len(cadence_num_bursts1000_3_100)):
    if cadence_num_bursts1000_3_100[i]!=0:
        cadence_new3_100.append(cadence_num_bursts1000_3_100[i])

data_3bin1000_log=[cadence_new3_100,cadence_new3_40,cadence_new3_16]

# %% [markdown]
# ## 4 bin

# %%
values1000_4bin=ascii.read('/Users/rachellee/Downloads/data/1000stars_only/values1000_4bin_2_week') 
burst_total1000_4=values1000_4bin['burst_total']
burst_total1000_4_3=values1000_4bin['burst_total3']
burst_total1000_4_16=values1000_4bin['burst_total16']
burst_total1000_4_40=values1000_4bin['burst_total40']
burst_total1000_4_100=values1000_4bin['burst_total100']
burst_num1000_4_3=values1000_4bin['burst_num3']
burst_num1000_4_16=values1000_4bin['burst_num16']
burst_num1000_4_40=values1000_4bin['burst_num40']
burst_num1000_4_100=values1000_4bin['burst_num100']

burst1000_4bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/burst1000_4.npy')
L1000_4bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/L1000_4.npy')
C1000_4bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/C1000_4.npy')

# %%
cadence_num_bursts1000_4_3=[]
cadence_num_bursts1000_4_16=[]
cadence_num_bursts1000_4_40=[]
cadence_num_bursts1000_4_100=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_4_3.append(burst_num1000_4_3[i][j])
        cadence_num_bursts1000_4_16.append(burst_num1000_4_16[i][j])
        cadence_num_bursts1000_4_40.append(burst_num1000_4_40[i][j])
        cadence_num_bursts1000_4_100.append(burst_num1000_4_100[i][j])

# %%
cadence_new4_3=[]
cadence_new4_16=[]
cadence_new4_40=[]
cadence_new4_100=[]
for i in range(len(cadence_num_bursts1000_4_3)):
    if cadence_num_bursts1000_4_3[i]!=0:
        cadence_new4_3.append(cadence_num_bursts1000_4_3[i])

for i in range(len(cadence_num_bursts1000_4_16)):
    if cadence_num_bursts1000_4_16[i]!=0:
        cadence_new4_16.append(cadence_num_bursts1000_4_16[i])

for i in range(len(cadence_num_bursts1000_4_40)):
    if cadence_num_bursts1000_4_40[i]!=0:
        cadence_new4_40.append(cadence_num_bursts1000_4_40[i])
        
for i in range(len(cadence_num_bursts1000_4_100)):
    if cadence_num_bursts1000_4_100[i]!=0:
        cadence_new4_100.append(cadence_num_bursts1000_4_100[i])

data_4bin1000_log=[cadence_new4_100,cadence_new4_40,cadence_new4_16,cadence_new4_3]

# %% [markdown]
# ## 5 bins

# %%
values1000_5bin=ascii.read('/Users/rachellee/Downloads/data/1000stars_only/values1000_5bin_2week') 
burst_total1000_5=values1000_5bin['burst_total']
burst_total1000_5_3=values1000_5bin['burst_total3']
burst_total1000_5_6=values1000_5bin['burst_total6']
burst_total1000_5_16=values1000_5bin['burst_total16']
burst_total1000_5_40=values1000_5bin['burst_total40']
burst_total1000_5_100=values1000_5bin['burst_total100']
burst_num1000_5_3=values1000_5bin['burst_num3']
burst_num1000_5_6=values1000_5bin['burst_num6']
burst_num1000_5_16=values1000_5bin['burst_num16']
burst_num1000_5_40=values1000_5bin['burst_num40']
burst_num1000_5_100=values1000_5bin['burst_num100']

burst1000_5bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/burst1000_5.npy')
L1000_5bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/L1000_5.npy')
C1000_5bin=np.load('/Users/rachellee/Downloads/data/1000stars_only/C1000_5.npy')

# %%
cadence_num_bursts1000_5_3=[]
cadence_num_bursts1000_5_6=[]
cadence_num_bursts1000_5_16=[]
cadence_num_bursts1000_5_40=[]
cadence_num_bursts1000_5_100=[]
for i in range(run):
    for j in t_list_cadence:
        cadence_num_bursts1000_5_3.append(burst_num1000_5_3[i][j])
        cadence_num_bursts1000_5_6.append(burst_num1000_5_6[i][j])        
        cadence_num_bursts1000_5_16.append(burst_num1000_5_16[i][j])
        cadence_num_bursts1000_5_40.append(burst_num1000_5_40[i][j])
        cadence_num_bursts1000_5_100.append(burst_num1000_5_100[i][j])

# %%
print(np.shape(burst_num1000_5_3))
# Out:
# (50, 7800)

# %%
cadence_new3=[]
cadence_new6=[]
cadence_new16=[]
cadence_new40=[]
cadence_new100=[]
for i in range(len(cadence_num_bursts1000_5_3)):
    if cadence_num_bursts1000_5_3[i]!=0:
        cadence_new3.append(cadence_num_bursts1000_5_3[i])
        
for i in range(len(cadence_num_bursts1000_5_6)):
    if cadence_num_bursts1000_5_6[i]!=0:
        cadence_new6.append(cadence_num_bursts1000_5_6[i])
        
for i in range(len(cadence_num_bursts1000_5_16)):
    if cadence_num_bursts1000_5_16[i]!=0:
        cadence_new16.append(cadence_num_bursts1000_5_16[i])
        
for i in range(len(cadence_num_bursts1000_5_40)):
    if cadence_num_bursts1000_5_40[i]!=0:
        cadence_new40.append(cadence_num_bursts1000_5_40[i])
        
for i in range(len(cadence_num_bursts1000_5_100)):
    if cadence_num_bursts1000_5_100[i]!=0:
        cadence_new100.append(cadence_num_bursts1000_5_100[i])
        
data_5bin1000_log=[cadence_new3,cadence_new6,cadence_new16,cadence_new40,cadence_new100]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(9,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(cadence_new100,positions=[10],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)
    
v40=ax1.violinplot(cadence_new40,positions=[4],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)
    
v16=ax1.violinplot(cadence_new16,positions=[1.6],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v3=ax1.violinplot(cadence_new3,positions=[0.3],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)   
    
v6=ax1.violinplot(cadence_new6,positions=[0.6],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)

ax1.set_xticklabels(['0','0','20','40','60','80','100'])

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Burst Amplitude',fontsize=15)
ax1.set_title('Number of bursts for each burst type (size=1000)',fontsize=20)

#ax1.set_xlim(1,200)
plt.yscale('log')
#plt.xscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp_1000_5bins_2week_log.jpeg',dpi=300,bbox_inches='tight')
# Out:
# <ipython-input-22-d7362c488a45>:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(['0','0','20','40','60','80','100'])

# %%
data100=[cadence_new1,cadence_new2_100,cadence_new3_100,cadence_new4_100,cadence_new100]
data40=[cadence_new2_40,cadence_new3_40,cadence_new4_40,cadence_new40]
data16=[cadence_new3_16,cadence_new4_16,cadence_new16]
data3=[cadence_new4_3,cadence_new3]
data6=[cadence_new6]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(8,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(data100,vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)

v40=ax1.violinplot(data40,positions=[2,3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)

v16=ax1.violinplot(data16,positions=[3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v6=ax1.violinplot(data6,positions=[5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

v3=ax1.violinplot(data3,positions=[4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)
    
ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)
    
ax1.scatter(1,np.mean(cadence_num_bursts1000_1),marker='_',s=300,color='#1f77b4',label='100x')
ax1.scatter(2,np.mean(cadence_num_bursts1000_2_40),marker='_',s=300,color='#ff7f0e',label='40x')
ax1.scatter(3,np.mean(cadence_num_bursts1000_3_16),marker='_',s=300,color='#2ca02c',label='16x')
ax1.scatter(5,np.mean(cadence_num_bursts1000_5_6),marker='_',s=300,color='#d62728',label='6x')
ax1.scatter(4,np.mean(cadence_num_bursts1000_4_3),marker='_',s=300,color='#9467bd',label='3x')
#ax1.scatter(6,np.mean(cadence_num_bursts2000_6_2),marker='_',s=300,color='#8c564b',label='2x')  
plt.legend(loc='upper left',fontsize=13)

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Number of burst types',fontsize=15)
ax1.set_title('Number of bursts for each burst type (size=1000)',fontsize=18)
plt.yscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp_1000_Allbins_logscale_2week.jpeg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## secondary observing cadence

# %%
dt_2week=2/52
dt_3month=0.25
dt_6month=0.5

step1=220+dt_2week
step2=step1+dt_3month
step3=step2+dt_6month
step4=step2+(2*dt_6month)
step5=step2+(3*dt_6month)
step6=step2+(4*dt_6month)
step7=step2+(5*dt_6month)
step8=step2+(6*dt_6month)
step9=step2+(7*dt_6month)

t_list_years2=[200,220,step1,step2,step3,step4,step5,step6,step7,step8,step9,225]
t_list_cadence2=[int(i*cadence) for i in t_list_years2]

# %%
cadence_num2_bursts1000_1=[]
for i in range(run):
    for j in t_list_cadence2:
        cadence_num2_bursts1000_1.append(burst_num1000_1[i][j])

# %%
cadence_num2_bursts1000_2_40=[]
cadence_num2_bursts1000_2_100=[]
for i in range(run):
    for j in t_list_cadence2:
        cadence_num2_bursts1000_2_40.append(burst_num1000_2_40[i][j])
        cadence_num2_bursts1000_2_100.append(burst_num1000_2_100[i][j])

# %%
cadence_num2_bursts1000_3_16=[]
cadence_num2_bursts1000_3_40=[]
cadence_num2_bursts1000_3_100=[]
for i in range(run):
    for j in t_list_cadence2:       
        cadence_num2_bursts1000_3_16.append(burst_num1000_3_16[i][j])
        cadence_num2_bursts1000_3_40.append(burst_num1000_3_40[i][j])
        cadence_num2_bursts1000_3_100.append(burst_num1000_3_100[i][j])

# %%
cadence_num2_bursts1000_4_3=[]
cadence_num2_bursts1000_4_16=[]
cadence_num2_bursts1000_4_40=[]
cadence_num2_bursts1000_4_100=[]
for i in range(run):
    for j in t_list_cadence2:
        cadence_num2_bursts1000_4_3.append(burst_num1000_4_3[i][j])      
        cadence_num2_bursts1000_4_16.append(burst_num1000_4_16[i][j])
        cadence_num2_bursts1000_4_40.append(burst_num1000_4_40[i][j])
        cadence_num2_bursts1000_4_100.append(burst_num1000_4_100[i][j])

# %%
cadence_num2_bursts1000_5_3=[]
cadence_num2_bursts1000_5_6=[]
cadence_num2_bursts1000_5_16=[]
cadence_num2_bursts1000_5_40=[]
cadence_num2_bursts1000_5_100=[]
for i in range(run):
    for j in t_list_cadence2:
        cadence_num2_bursts1000_5_3.append(burst_num1000_5_3[i][j])
        cadence_num2_bursts1000_5_6.append(burst_num1000_5_6[i][j])        
        cadence_num2_bursts1000_5_16.append(burst_num1000_5_16[i][j])
        cadence_num2_bursts1000_5_40.append(burst_num1000_5_40[i][j])
        cadence_num2_bursts1000_5_100.append(burst_num1000_5_100[i][j])

# %%
cadence2_new3=[]
cadence2_new6=[]
cadence2_new16=[]
cadence2_new40=[]
cadence2_new100=[]
for i in range(len(cadence_num2_bursts1000_5_3)):
    if cadence_num2_bursts1000_5_3[i]!=0:
        cadence2_new3.append(cadence_num2_bursts1000_5_3[i])
        
for i in range(len(cadence_num2_bursts1000_5_6)):
    if cadence_num2_bursts1000_5_6[i]!=0:
        cadence2_new6.append(cadence_num2_bursts1000_5_6[i])
        
for i in range(len(cadence_num2_bursts1000_5_16)):
    if cadence_num2_bursts1000_5_16[i]!=0:
        cadence2_new16.append(cadence_num2_bursts1000_5_16[i])
        
for i in range(len(cadence_num2_bursts1000_5_40)):
    if cadence_num2_bursts1000_5_40[i]!=0:
        cadence2_new40.append(cadence_num2_bursts1000_5_40[i])
        
for i in range(len(cadence_num2_bursts1000_5_100)):
    if cadence_num2_bursts1000_5_100[i]!=0:
        cadence2_new100.append(cadence_num2_bursts1000_5_100[i])
        
data2_5bin1000_log=[cadence2_new3,cadence2_new6,cadence2_new16,cadence2_new40,cadence2_new100]
data2_6_log=[cadence2_new6]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(9,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(cadence2_new100,positions=[10],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)
    
v40=ax1.violinplot(cadence2_new40,positions=[4],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)
    
v16=ax1.violinplot(cadence2_new16,positions=[1.6],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v3=ax1.violinplot(cadence2_new3,positions=[0.3],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)   
    
v6=ax1.violinplot(cadence2_new6,positions=[0.6],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)

ax1.set_xticklabels(['0','0','20','40','60','80','100'])

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Burst Amplitude',fontsize=15)
ax1.set_title('Number of bursts for each burst type (size=1000)',fontsize=20)

#ax1.set_xlim(1,200)
plt.yscale('log')
#plt.xscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp2_1000_5bins_2week_log.jpeg',dpi=300,bbox_inches='tight')
# Out:
# <ipython-input-34-d3361a105d3e>:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(['0','0','20','40','60','80','100'])

# %%
data2_100=[cadence_num2_bursts1000_1,cadence_num2_bursts1000_2_100,cadence_num2_bursts1000_3_100,\
        cadence_num2_bursts1000_4_100,cadence_num2_bursts1000_5_100]
data2_40=[cadence_num2_bursts1000_2_40,cadence_num2_bursts1000_3_40,cadence_num2_bursts1000_4_40,\
        cadence_num2_bursts1000_5_40]
data2_16=[cadence_num2_bursts1000_3_16,cadence_num2_bursts1000_4_16,cadence_num2_bursts1000_5_16]
data2_6=[cadence_num2_bursts1000_5_6]
data2_3=[cadence_num2_bursts1000_4_3,cadence_num2_bursts1000_5_3]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(9,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'


#ax1
v100=ax1.violinplot(data2_100,vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)

v40=ax1.violinplot(data2_40,positions=[2,3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)

v16=ax1.violinplot(data2_16,positions=[3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v6=ax1.violinplot(data2_6,positions=[5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

v3=ax1.violinplot(data2_3,positions=[4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)
    
ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)
    
ax1.scatter(1,np.mean(cadence_num2_bursts1000_1),marker='_',s=300,color='#1f77b4',label='100x')
ax1.scatter(2,np.mean(cadence_num2_bursts1000_2_40),marker='_',s=300,color='#ff7f0e',label='40x')
ax1.scatter(3,np.mean(cadence_num2_bursts1000_3_16),marker='_',s=300,color='#2ca02c',label='16x')
ax1.scatter(5,np.mean(cadence_num2_bursts1000_5_6),marker='_',s=300,color='#d62728',label='6x')
ax1.scatter(5,np.mean(cadence_num2_bursts1000_5_3),marker='_',s=300,color='#9467bd',label='3x')
#ax1.scatter(6,np.mean(cadence_num_bursts2000_6_2),marker='_',s=300,color='#8c564b',label='2x')  
plt.legend(loc='upper left',fontsize=12)

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Number of burst types',fontsize=15)
ax1.set_title('Number of bursts for each burst type (size=1000)',fontsize=18)
#plt.yscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp2_1000_AllBins_normalscale_2week.jpeg',dpi=300,bbox_inches='tight')

# %%
#make it log scale?
data2_100new=[]
list2_100=[]
for i in range(5):
    for j in range(600):
        if data2_100[i][j]!=0:
            list2_100.append(data2_100[i][j])
    data2_100new.append(list2_100)
    list2_100=[]
    
data2_40new=[]
list2_40=[]
for i in range(4):
    for j in range(600):
        if data2_40[i][j]!=0:
            list2_40.append(data2_40[i][j])
    data2_40new.append(list2_40)
    list2_40=[]
    
data2_16new=[]
list2_16=[]
for i in range(3):
    for j in range(600):
        if data2_16[i][j]!=0:
            list2_16.append(data2_16[i][j])
    data2_16new.append(list2_16)
    list2_16=[]
    
data2_6new=[]
list2_6=[]
for i in range(1):
    for j in range(600):
        if data2_6[i][j]!=0:
            list2_6.append(data2_6[i][j])
    data2_6new.append(list2_6)
    list2_6=[]
    
data2_3new=[]
list2_3=[]
for i in range(2):
    for j in range(600):
        if data2_3[i][j]!=0:
            list2_3.append(data2_3[i][j])
    data2_3new.append(list2_3)
    list2_3=[]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(8,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(data2_100new,vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)

v40=ax1.violinplot(data2_40new,positions=[2,3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)

v16=ax1.violinplot(data2_16new,positions=[3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v6=ax1.violinplot(data2_6new,positions=[5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

v3=ax1.violinplot(data2_3new,positions=[4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)
    
ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)
    
ax1.scatter(1,np.mean(cadence_num2_bursts1000_1),marker='_',s=300,color='#1f77b4',label='100x')
ax1.scatter(2,np.mean(cadence_num2_bursts1000_2_40),marker='_',s=300,color='#ff7f0e',label='40x')
ax1.scatter(3,np.mean(cadence_num2_bursts1000_3_16),marker='_',s=300,color='#2ca02c',label='16x')
ax1.scatter(5,np.mean(cadence_num2_bursts1000_5_6),marker='_',s=300,color='#d62728',label='6x')
ax1.scatter(5,np.mean(cadence_num2_bursts1000_5_3),marker='_',s=300,color='#9467bd',label='3x')
#ax1.scatter(6,np.mean(cadence_num_bursts2000_6_2),marker='_',s=300,color='#8c564b',label='2x')  
plt.legend(loc='upper left',fontsize=13)

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Number of burst types',fontsize=15)
ax1.set_title('Number of bursts for each burst type (size=1000)',fontsize=18)
plt.yscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp2_1000_Allbins_logscale_2week.jpeg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Number of bursts in an entire observing run

# %% [markdown]
# ## 1 bin

# %%
cluster_size=1000

cad_C1000_1bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_C1000_1bin[i,j,k]=C1000_1bin[i,j,t_list_cadence[k]]

# %%
num1000_1bin=0
num1000_1bin_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if cad_C1000_1bin[i,k,j]==100:
                num1000_1bin+=1
    num1000_1bin_list.append(num1000_1bin)
    num1000_1bin=0

# %% [markdown]
# ## 2 bins

# %%
cad_C1000_2bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_C1000_2bin[i,j,k]=C1000_2bin[i,j,t_list_cadence[k]]

# %%
num1000_2bin40=0
num1000_2bin40_list=[]
num1000_2bin100=0
num1000_2bin100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if cad_C1000_2bin[i,k,j]==100:
                num1000_2bin100+=1
            elif cad_C1000_2bin[i,k,j]==40:
                num1000_2bin40+=1
    num1000_2bin40_list.append(num1000_2bin40)
    num1000_2bin40=0
    num1000_2bin100_list.append(num1000_2bin100)
    num1000_2bin100=0

# %% [markdown]
# ## 3 bins

# %%
cad_C1000_3bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_C1000_3bin[i,j,k]=C1000_3bin[i,j,t_list_cadence[k]]

# %%
num1000_3bin16=0
num1000_3bin16_list=[]
num1000_3bin40=0
num1000_3bin40_list=[]
num1000_3bin100=0
num1000_3bin100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if cad_C1000_3bin[i,k,j]==100:
                num1000_3bin100+=1
            elif cad_C1000_3bin[i,k,j]==40:
                num1000_3bin40+=1
            elif cad_C1000_3bin[i,k,j]==16:
                num1000_3bin16+=1
    num1000_3bin16_list.append(num1000_3bin16)
    num1000_3bin16=0
    num1000_3bin40_list.append(num1000_3bin40)
    num1000_3bin40=0
    num1000_3bin100_list.append(num1000_3bin100)
    num1000_3bin100=0

# %% [markdown]
# ## 4 bins

# %%
cad_C1000_4bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_C1000_4bin[i,j,k]=C1000_4bin[i,j,t_list_cadence[k]]

# %%
num1000_4bin3=0
num1000_4bin3_list=[]
num1000_4bin16=0
num1000_4bin16_list=[]
num1000_4bin40=0
num1000_4bin40_list=[]
num1000_4bin100=0
num1000_4bin100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if cad_C1000_4bin[i,k,j]==100:
                num1000_4bin100+=1
            elif cad_C1000_4bin[i,k,j]==40:
                num1000_4bin40+=1
            elif cad_C1000_4bin[i,k,j]==16:
                num1000_4bin16+=1
            elif cad_C1000_4bin[i,k,j]==3:
                num1000_4bin3+=1
    num1000_4bin3_list.append(num1000_4bin3)
    num1000_4bin3=0
    num1000_4bin16_list.append(num1000_4bin16)
    num1000_4bin16=0
    num1000_4bin40_list.append(num1000_4bin40)
    num1000_4bin40=0
    num1000_4bin100_list.append(num1000_4bin100)
    num1000_4bin100=0

# %% [markdown]
# ## 5 bins

# %%
cad_C1000_5bin=np.zeros((run,cluster_size,12))
for i in range(run):
    for j in range(cluster_size):
        for k in range(len(t_list_cadence)):
                cad_C1000_5bin[i,j,k]=C1000_5bin[i,j,t_list_cadence[k]]

# %%
num1000_5bin6=0
num1000_5bin6_list=[]
num1000_5bin3=0
num1000_5bin3_list=[]
num1000_5bin16=0
num1000_5bin16_list=[]
num1000_5bin40=0
num1000_5bin40_list=[]
num1000_5bin100=0
num1000_5bin100_list=[]
for i in range(run):
    for j in range(0,12):
        for k in range(cluster_size):
            if cad_C1000_5bin[i,k,j]==100:
                num1000_5bin100+=1
            elif cad_C1000_5bin[i,k,j]==40:
                num1000_5bin40+=1
            elif cad_C1000_5bin[i,k,j]==16:
                num1000_5bin16+=1
            elif cad_C1000_5bin[i,k,j]==3:
                num1000_5bin3+=1
            elif cad_C1000_5bin[i,k,j]==6:
                num1000_5bin6+=1
    num1000_5bin6_list.append(num1000_5bin6)
    num1000_5bin6=0
    num1000_5bin3_list.append(num1000_5bin3)
    num1000_5bin3=0
    num1000_5bin16_list.append(num1000_5bin16)
    num1000_5bin16=0
    num1000_5bin40_list.append(num1000_5bin40)
    num1000_5bin40=0
    num1000_5bin100_list.append(num1000_5bin100)
    num1000_5bin100=0

# %%
#make it log
cad_new1000_1bin=[]
for i in range(len(num1000_1bin_list)):
    if num1000_1bin_list[i]!=0:
        cad_new1000_1bin.append(num1000_1bin_list[i])
        
cad_new1000_2bin40=[]
cad_new1000_2bin100=[]
for i in range(len(num1000_2bin100_list)):
    if num1000_2bin100_list[i]!=0:
        cad_new1000_2bin100.append(num1000_2bin100_list[i])
for i in range(len(num1000_2bin40_list)):
    if num1000_2bin40_list[i]!=0:
        cad_new1000_2bin40.append(num1000_2bin40_list[i])
        
cad_new1000_3bin16=[]
cad_new1000_3bin40=[]
cad_new1000_3bin100=[]
for i in range(len(num1000_3bin100_list)):
    if num1000_3bin100_list[i]!=0:
        cad_new1000_3bin100.append(num1000_3bin100_list[i])
for i in range(len(num1000_3bin40_list)):
    if num1000_3bin40_list[i]!=0:
        cad_new1000_3bin40.append(num1000_3bin40_list[i])
for i in range(len(num1000_3bin16_list)):
    if num1000_3bin16_list[i]!=0:
        cad_new1000_3bin16.append(num1000_3bin16_list[i])
        
cad_new1000_4bin3=[]
cad_new1000_4bin16=[]
cad_new1000_4bin40=[]
cad_new1000_4bin100=[]
for i in range(len(num1000_4bin100_list)):
    if num1000_4bin100_list[i]!=0:
        cad_new1000_4bin100.append(num1000_4bin100_list[i])
for i in range(len(num1000_4bin40_list)):
    if num1000_4bin40_list[i]!=0:
        cad_new1000_4bin40.append(num1000_4bin40_list[i])
for i in range(len(num1000_4bin16_list)):
    if num1000_4bin16_list[i]!=0:
        cad_new1000_4bin16.append(num1000_4bin16_list[i])
for i in range(len(num1000_4bin3_list)):
    if num1000_4bin3_list[i]!=0:
        cad_new1000_4bin3.append(num1000_4bin3_list[i])
        
cad_new1000_5bin6=[]
cad_new1000_5bin3=[]
cad_new1000_5bin16=[]
cad_new1000_5bin40=[]
cad_new1000_5bin100=[]
for i in range(len(num1000_5bin100_list)):
    if num1000_5bin100_list[i]!=0:
        cad_new1000_5bin100.append(num1000_5bin100_list[i])
for i in range(len(num1000_5bin40_list)):
    if num1000_5bin40_list[i]!=0:
        cad_new1000_5bin40.append(num1000_5bin40_list[i])
for i in range(len(num1000_5bin16_list)):
    if num1000_5bin16_list[i]!=0:
        cad_new1000_5bin16.append(num1000_5bin16_list[i])
for i in range(len(num1000_5bin3_list)):
    if num1000_5bin3_list[i]!=0:
        cad_new1000_5bin3.append(num1000_5bin3_list[i])
for i in range(len(num1000_5bin6_list)):
    if num1000_5bin6_list[i]!=0:
        cad_new1000_5bin6.append(num1000_5bin6_list[i])

# %%
datanew100=[cad_new1000_1bin,cad_new1000_2bin100,cad_new1000_3bin100,cad_new1000_4bin100,cad_new1000_5bin100]
datanew40=[cad_new1000_2bin40,cad_new1000_3bin40,cad_new1000_4bin40,cad_new1000_5bin40]
datanew16=[cad_new1000_3bin16,cad_new1000_4bin16,cad_new1000_5bin16]
datanew3=[cad_new1000_4bin3,cad_new1000_5bin3]
datanew6=[cad_new1000_5bin6]

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(9,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(cad_new1000_5bin100,positions=[10],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)
    
v40=ax1.violinplot(cad_new1000_5bin40,positions=[4],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)
    
v16=ax1.violinplot(cad_new1000_5bin16,positions=[1.6],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v3=ax1.violinplot(cad_new1000_5bin3,positions=[0.3],vert=True, widths=0.5, showmeans=True, showextrema=True, showmedians=False)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)   
    
v6=ax1.violinplot(cad_new1000_5bin6,positions=[0.6],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)

ax1.set_xticklabels(['0','0','20','40','60','80','100'])

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Burst Amplitude',fontsize=15)
ax1.set_title('Total number of bursts in an observing run for each burst type (size=1000)',fontsize=15)

#ax1.set_xlim(1,200)
plt.yscale('log')
#plt.xscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp_1000_5bins_FullRun.jpeg',dpi=300,bbox_inches='tight')
# Out:
# <ipython-input-53-b51fee8aef15>:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(['0','0','20','40','60','80','100'])

# %%
fig,ax1=plt.subplots()
fig.set_size_inches(8,7)
plt.rcParams['text.usetex']='False'
plt.rcParams['font.family']='sans serif'
plt.rcParams['axes.labelweight']='normal'
plt.rcParams['font.weight']='normal'

#ax1
v100=ax1.violinplot(datanew100,vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v100['bodies']:
    pc.set_facecolor('#1f77b4')
    pc.set_edgecolor('#1f77b4')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v100[partname]
    vp.set_edgecolor('#1f77b4')
    vp.set_linewidth(2)

v40=ax1.violinplot(datanew40,positions=[2,3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v40['bodies']:
    pc.set_facecolor('#ff7f0e')
    pc.set_edgecolor('#ff7f0e')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v40[partname]
    vp.set_edgecolor('#ff7f0e')
    vp.set_linewidth(2)

v16=ax1.violinplot(datanew16,positions=[3,4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v16['bodies']:
    pc.set_facecolor('#2ca02c')
    pc.set_edgecolor('#2ca02c')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v16[partname]
    vp.set_edgecolor('#2ca02c')
    vp.set_linewidth(2)
    
v6=ax1.violinplot(datanew6,positions=[5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v6['bodies']:
    pc.set_facecolor('#d62728')
    pc.set_edgecolor('#d62728')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v6[partname]
    vp.set_edgecolor('#d62728')
    vp.set_linewidth(2)

v3=ax1.violinplot(datanew3,positions=[4,5],vert=True, widths=0.5, showmeans=True, showextrema=True)
for pc in v3['bodies']:
    pc.set_facecolor('#9467bd')
    pc.set_edgecolor('#9467bd')
    pc.set_alpha(0.3)
for partname in ('cbars','cmins','cmaxes','cmeans',):
    vp=v3[partname]
    vp.set_edgecolor('#9467bd')
    vp.set_linewidth(2)
    
ax1.minorticks_on()
ax1.locator_params(axis='y',nbins=6)
#ax1.yaxis.set_ticks_position('both')
#ax1.tick_params(axis='both',right=True,top=True,which='both')
ax1.tick_params(axis='both',which='major', length=10, width=1, direction='in',labelsize=15)
ax1.tick_params(axis='both',which='minor', length=5, width=1, direction='in',labelsize=15)
    
ax1.scatter(1,np.mean(cad_new1000_1bin),marker='_',s=300,color='#1f77b4',label='100x')
ax1.scatter(2,np.mean(cad_new1000_2bin40),marker='_',s=300,color='#ff7f0e',label='40x')
ax1.scatter(3,np.mean(cad_new1000_3bin16),marker='_',s=300,color='#2ca02c',label='16x')
ax1.scatter(5,np.mean(cad_new1000_5bin6),marker='_',s=300,color='#d62728',label='6x')
ax1.scatter(4,np.mean(cad_new1000_4bin3),marker='_',s=300,color='#9467bd',label='3x')
#ax1.scatter(6,np.mean(cadence_num_bursts2000_6_2),marker='_',s=300,color='#8c564b',label='2x')  
plt.legend(loc='lower left',fontsize=13)

ax1.set_ylabel(r'Number of stars undergoing a burst',fontsize=15)
ax1.set_xlabel('Number of burst types',fontsize=15)
ax1.set_title('Number of bursts in an observing run for each burst type (size=1000)',fontsize=15)
plt.yscale('log')

plt.plot()
plt.savefig('/Users/rachellee/Desktop/research/figs/size1000/comp_1000_Allbins_FullRun.jpeg',dpi=300,bbox_inches='tight')
